# %%
BASE = "/content/coco_fruits"

# %%
import os, subprocess, pathlib

os.makedirs(BASE, exist_ok=True)
os.makedirs(f"{BASE}/coco", exist_ok=True)

# Install pycocotools
# !pip -q install pycocotools tqdm

# Download train2017 images (18GB). Comment this if already present.
if not pathlib.Path(f"{BASE}/coco/train2017.zip").exists():
    # !wget -q http://images.cocodataset.org/zips/train2017.zip -O "{BASE}/coco/train2017.zip"

# Download annotations
if not pathlib.Path(f"{BASE}/coco/annotations_trainval2017.zip").exists():
    # !wget -q http://images.cocodataset.org/annotations/annotations_trainval2017.zip -O "{BASE}/coco/annotations_trainval2017.zip"

# Unzip
if not pathlib.Path(f"{BASE}/coco/train2017").exists():
    # !unzip -q "{BASE}/coco/train2017.zip" -d "{BASE}/coco/"

if not pathlib.Path(f"{BASE}/coco/annotations").exists():
    # !unzip -q "{BASE}/coco/annotations_trainval2017.zip" -d "{BASE}/coco/"

# %%
# ====== CONFIG ======
BASE = "/content/coco_fruits"  # or your Drive path
ROOT_OUT = f"{BASE}/coco_fruits_by_class"
COCO_DIR = f"{BASE}/coco"  # where train2017 + annotations live (from your previous step)
ANN = f"{COCO_DIR}/annotations/instances_train2017.json"
IMAGES = f"{COCO_DIR}/train2017"

CLASSES = ["banana", "apple", "orange"]
PER_CLASS_MAX = 1000          # images per class
VAL_RATIO = 0.10
RANDOM_SEED = 42
# =====================

import json, os, random, shutil
from pathlib import Path
from collections import defaultdict
from tqdm import tqdm

random.seed(RANDOM_SEED)
Path(ROOT_OUT).mkdir(parents=True, exist_ok=True)

# Load COCO
with open(ANN, "r") as f:
    data = json.load(f)

cat_id_to_name = {c["id"]: c["name"] for c in data["categories"]}
name_to_cat_id = {v:k for k,v in cat_id_to_name.items()}

target_cat_ids = {name_to_cat_id[n] for n in CLASSES if n in name_to_cat_id}
imginfo = {im["id"]: im for im in data["images"]}

# Gather anns per image for target classes
anns_by_img = defaultdict(list)
for a in data["annotations"]:
    if a.get("iscrowd",0) == 1:
        continue
    if a.get("segmentation") and a["category_id"] in target_cat_ids:
        anns_by_img[a["image_id"]].append(a)

# Build image lists per class
images_for_class = {c: [] for c in CLASSES}
for img_id, anns in anns_by_img.items():
    present = set(cat_id_to_name[a["category_id"]] for a in anns)
    for c in CLASSES:
        if c in present:
            images_for_class[c].append(img_id)

def coco_polys_from_ann(ann):
    seg = ann.get("segmentation")
    if isinstance(seg, list):
        return [poly for poly in seg if isinstance(poly, list) and len(poly) >= 6]
    return []

def poly_to_yolo_line(poly, cls_id, W, H):
    xs = poly[0::2]; ys = poly[1::2]
    nx = [x / W for x in xs]
    ny = [y / H for y in ys]
    coords = []
    for x,y in zip(nx,ny):
        coords += [x,y]
    return f"{cls_id} " + " ".join(f"{v:.6f}" for v in coords)

# For each class, pick up to PER_CLASS_MAX unique images
for cname in CLASSES:
    selected = list(dict.fromkeys(images_for_class[cname]))  # de-dup, keep order
    random.shuffle(selected)
    selected = selected[:PER_CLASS_MAX]

    # Split
    val_n = max(1, int(len(selected) * VAL_RATIO))
    val_ids = set(selected[:val_n])
    train_ids = set(selected[val_n:])

    # Prepare folders
    for split in ["train","val"]:
        Path(f"{ROOT_OUT}/{cname}/images/{split}").mkdir(parents=True, exist_ok=True)
        Path(f"{ROOT_OUT}/{cname}/labels/{split}").mkdir(parents=True, exist_ok=True)

    # YOLO class index: only this class = 0
    class_index = {cname: 0}

    def export_one(img_id, split):
        info = imginfo[img_id]
        W,H = info["width"], info["height"]
        src_name = Path(info["file_name"]).name
        src_img = Path(IMAGES) / src_name
        dst_img = Path(f"{ROOT_OUT}/{cname}/images/{split}") / src_name
        dst_lbl = Path(f"{ROOT_OUT}/{cname}/labels/{split}") / (Path(src_name).stem + ".txt")

        # keep ONLY this class in the label
        lines = []
        for a in anns_by_img[img_id]:
            if cat_id_to_name[a["category_id"]] != cname:
                continue
            for poly in coco_polys_from_ann(a):
                lines.append(poly_to_yolo_line(poly, 0, W, H))  # class id 0

        if lines:
            shutil.copy2(src_img, dst_img)
            dst_lbl.write_text("\n".join(lines), encoding="utf-8")

    # Write files
    print(f"Exporting {cname} (train: {len(train_ids)}, val: {len(val_ids)})...")
    for img_id in tqdm(train_ids):
        export_one(img_id, "train")
    for img_id in tqdm(val_ids):
        export_one(img_id, "val")

    # Write a small data.yaml for each class
    Path(f"{ROOT_OUT}/{cname}/data.yaml").write_text(f"""# {cname} (COCO subset) for YOLO segmentation
path: {Path(f"{ROOT_OUT}/{cname}").resolve()}
train: images/train
val: images/val
names: ['{cname}']
""", encoding="utf-8")

print("Done. Root:", ROOT_OUT)
# Out:
# Exporting banana (train: 900, val: 100)...
# 100%|██████████| 900/900 [00:03<00:00, 229.16it/s]
# 100%|██████████| 100/100 [00:00<00:00, 280.14it/s]
# Exporting apple (train: 900, val: 100)...
# 100%|██████████| 900/900 [00:02<00:00, 325.47it/s]
# 100%|██████████| 100/100 [00:00<00:00, 351.74it/s]
# Exporting orange (train: 900, val: 100)...
# 100%|██████████| 900/900 [00:02<00:00, 374.31it/s]
# 100%|██████████| 100/100 [00:00<00:00, 398.72it/s]
# Done. Root: /content/coco_fruits/coco_fruits_by_class

# %%
# 2) Choose a destination inside Drive (change the folder name if you want)
DEST = "/content/drive/MyDrive/3fruits"

# 3) Copy everything over (keeps subfolders and timestamps)
# !mkdir -p "$DEST"
# !rsync -ah --progress "/content/Strawberry" "$DEST/"
# Out:
# Streaming output truncated to the last 5000 lines.
# Strawberry/train/images/fresa_375_jpg.rf.fc26e223c5fafdda226f55b7e2b2dfef.jpg
#          45.59K 100%  947.31kB/s    0:00:00 (xfr#1346, ir-chk=2289/3643)
# Strawberry/train/images/fresa_376_jpg.rf.16a3cd6612a804bea43c1f1020c40bb6.jpg
#          39.86K 100%  505.52kB/s    0:00:00 (xfr#1347, ir-chk=2288/3643)
# Strawberry/train/images/fresa_376_jpg.rf.bea465679691d2edcbbbbafc55f742cf.jpg
#          40.33K 100%  315.06kB/s    0:00:00 (xfr#1348, ir-chk=2287/3643)
# Strawberry/train/images/fresa_376_jpg.rf.ff0d20cc7a2db6d97ba5702f701111ce.jpg
#          40.38K 100%  266.45kB/s    0:00:00 (xfr#1349, ir-chk=2286/3643)
# Strawberry/train/images/fresa_377_jpg.rf.82df42497d6e3fd534ba18198cb34891.jpg
#          41.67K 100%  239.36kB/s    0:00:00 (xfr#1350, ir-chk=2285/3643)
# Strawberry/train/images/fresa_377_jpg.rf.8b729174c094eed13f6bdc55dfe0ca25.jpg
#          39.48K 100%  199.78kB/s    0:00:00 (xfr#1351, ir-chk=2284/3643)
# Strawberry/train/images/fresa_377_jpg.rf.946002bc96194b87625d4dc59b1f3cdf.jpg
#          40.88K 100%  185.66kB/s    0:00:00 (xfr#1352, ir-chk=2283/3643)
# Strawberry/train/images/fresa_379_jpg.rf.0aed938386beb3e82656af5000447aea.jpg
#          35.71K 100%  146.53kB/s    0:00:00 (xfr#1353, ir-chk=2282/3643)
# Strawberry/train/images/fresa_379_jpg.rf.43a6896828d1a204e73689f14bb0f8d5.jpg
#          35.46K 100%  132.67kB/s    0:00:00 (xfr#1354, ir-chk=2281/3643)
# Strawberry/train/images/fresa_379_jpg.rf.53b4597f9c568e64a80da7e0cef4f95b.jpg
#          34.88K 100%  119.53kB/s    0:00:00 (xfr#1355, ir-chk=2280/3643)
# Strawberry/train/images/fresa_381_jpg.rf.41bb5de9e89816d3224da0a233d60c0b.jpg
#          30.96K 100%   89.72kB/s    0:00:00 (xfr#1356, ir-chk=2279/3643)
# Strawberry/train/images/fresa_381_jpg.rf.6ede7476e60eff488e4e7c02eb49bf60.jpg
#          29.85K 100%   86.24kB/s    0:00:00 (xfr#1357, ir-chk=2278/3643)
# Strawberry/train/images/fresa_381_jpg.rf.776eb15082b30a5cbfc7d5b7f97f4fcb.jpg
#          29.74K 100%   77.64kB/s    0:00:00 (xfr#1358, ir-chk=2277/3643)
# Strawberry/train/images/fresa_383_jpg.rf.596d45dbbbf1c43c8edbe80220eb3313.jpg
#          34.58K 100%   90.29kB/s    0:00:00 (xfr#1359, ir-chk=2276/3643)
# Strawberry/train/images/fresa_383_jpg.rf.de11b54a9d85faa849d1f8c8fad0d4ea.jpg
#          34.47K 100%   61.87kB/s    0:00:00 (xfr#1360, ir-chk=2275/3643)
# Strawberry/train/images/fresa_383_jpg.rf.fe810d936f82324cb7e5b94b0af995f0.jpg
#          35.98K 100%   53.97kB/s    0:00:00 (xfr#1361, ir-chk=2274/3643)
# Strawberry/train/images/fresa_384_jpg.rf.43fa1fcc8ba35e1582245b5fbc121449.jpg
#          32.05K 100%   48.08kB/s    0:00:00 (xfr#1362, ir-chk=2273/3643)
# Strawberry/train/images/fresa_384_jpg.rf.58db0b028c5b5bf8e6189fdbba6adcf0.jpg
#          34.76K 100%   46.06kB/s    0:00:00 (xfr#1363, ir-chk=2272/3643)
# Strawberry/train/images/fresa_384_jpg.rf.da7cb593e3cc13e1c7cb48479b3c8b97.jpg
#          30.32K 100%   40.17kB/s    0:00:00 (xfr#1364, ir-chk=2271/3643)
# Strawberry/train/images/fresa_385_jpg.rf.783ee6eb5a6870602ccbe58d3185e349.jpg
#          40.05K 100%   47.34kB/s    0:00:00 (xfr#1365, ir-chk=2270/3643)
# Strawberry/train/images/fresa_385_jpg.rf.81031f73522c7fdda0ee4724bc4303f1.jpg
#          40.04K 100%   47.33kB/s    0:00:00 (xfr#1366, ir-chk=2269/3643)
# Strawberry/train/images/fresa_385_jpg.rf.8fd1183295ef257667e719c7aad02504.jpg
#          41.00K 100%   40.77kB/s    0:00:00 (xfr#1367, ir-chk=2268/3643)
# Strawberry/train/images/fresa_386_jpg.rf.361a513ae4e4da89bc9fe44f67c321ef.jpg
#          24.99K 100%   24.85kB/s    0:00:00 (xfr#1368, ir-chk=2267/3643)
# Strawberry/train/images/fresa_386_jpg.rf.423f86dd2f1120bf648ef9107a834ed6.jpg
#          21.19K 100%   21.07kB/s    0:00:00 (xfr#1369, ir-chk=2266/3643)
# Strawberry/train/images/fresa_386_jpg.rf.eb56c79b8136930b43a0c5e6d286fc17.jpg
#          24.22K 100%   21.92kB/s    0:00:01 (xfr#1370, ir-chk=2265/3643)
# Strawberry/train/images/fresa_389_jpg.rf.0e5d3ece4abdbdef7c88241ffe0287a5.jpg
#          43.46K 100%   36.84kB/s    0:00:01 (xfr#1371, ir-chk=2264/3643)
# Strawberry/train/images/fresa_389_jpg.rf.867d957f56bb86c50324dfe37982a1c6.jpg
#          40.57K 100%   38.69MB/s    0:00:00 (xfr#1372, ir-chk=2263/3643)
# Strawberry/train/images/fresa_389_jpg.rf.bfe517dc4a52db813a2d7a365e517e6a.jpg
#          42.45K 100%  208.33kB/s    0:00:00 (xfr#1373, ir-chk=2262/3643)
# Strawberry/train/images/fresa_390_jpg.rf.42cd7a7747c64c65e4fef8eacecc5b02.jpg
#          36.51K 100%  155.03kB/s    0:00:00 (xfr#1374, ir-chk=2261/3643)
# Strawberry/train/images/fresa_390_jpg.rf.793e1c5f71a87c34b1df6dc0f60483a3.jpg
#          35.95K 100%  152.66kB/s    0:00:00 (xfr#1375, ir-chk=2260/3643)
# Strawberry/train/images/fresa_390_jpg.rf.eb0db8fc9140bae72c392ba6a0fbc257.jpg
#          34.91K 100%  123.06kB/s    0:00:00 (xfr#1376, ir-chk=2259/3643)
# Strawberry/train/images/fresa_392_jpg.rf.33508625390b82cfd08f695c061e2318.jpg
#          35.60K 100%   96.32kB/s    0:00:00 (xfr#1377, ir-chk=2258/3643)
# Strawberry/train/images/fresa_392_jpg.rf.8ba74fbe4cabe1114ec48318179c88ba.jpg
#          33.17K 100%   73.46kB/s    0:00:00 (xfr#1378, ir-chk=2257/3643)
# Strawberry/train/images/fresa_392_jpg.rf.b2c3c3b153210c3ede2c21edb8bc4c03.jpg
#          36.02K 100%   70.49kB/s    0:00:00 (xfr#1379, ir-chk=2256/3643)
# Strawberry/train/images/fresa_393_jpg.rf.2a85d1fd866ea0a24c6ef20333976000.jpg
#          30.19K 100%   55.94kB/s    0:00:00 (xfr#1380, ir-chk=2255/3643)
# Strawberry/train/images/fresa_393_jpg.rf.30d45d3f335d6df2399d84d09ad92a96.jpg
#          29.89K 100%   55.39kB/s    0:00:00 (xfr#1381, ir-chk=2254/3643)
# Strawberry/train/images/fresa_393_jpg.rf.caf9e08552d645f9e3f5c86dc507609e.jpg
#          28.95K 100%   51.12kB/s    0:00:00 (xfr#1382, ir-chk=2253/3643)
# Strawberry/train/images/fresa_394_jpg.rf.581f84bfb88954749a12e373ad495ec4.jpg
#          42.14K 100%   51.24kB/s    0:00:00 (xfr#1383, ir-chk=2252/3643)
# Strawberry/train/images/fresa_394_jpg.rf.68eed5a88289be3d1197d4d451078092.jpg
#          37.30K 100%   45.36kB/s    0:00:00 (xfr#1384, ir-chk=2251/3643)
# Strawberry/train/images/fresa_394_jpg.rf.e6357256cf06af6d9b86c7f7b9fa9477.jpg
#          39.21K 100%   43.91kB/s    0:00:00 (xfr#1385, ir-chk=2250/3643)
# Strawberry/train/images/fresa_395_jpg.rf.5686621b4ed3ba943821c96a8a31700e.jpg
#          24.81K 100%   27.78kB/s    0:00:00 (xfr#1386, ir-chk=2249/3643)
# Strawberry/train/images/fresa_395_jpg.rf.6bb83b2121876c2839691ebb4dbe599a.jpg
#          22.68K 100%   25.40kB/s    0:00:00 (xfr#1387, ir-chk=2248/3643)
# Strawberry/train/images/fresa_395_jpg.rf.a32dc0d229a52afd0d3a85de6a4081e0.jpg
#          20.69K 100%   23.17kB/s    0:00:00 (xfr#1388, ir-chk=2247/3643)
# Strawberry/train/images/fresa_397_jpg.rf.85f002d23a052a9eaa6160175cbc1a92.jpg
#          35.34K 100%   37.55kB/s    0:00:00 (xfr#1389, ir-chk=2246/3643)
# Strawberry/train/images/fresa_397_jpg.rf.b6c15c3b424fa04d11758020f151a956.jpg
#          37.62K 100%   39.97kB/s    0:00:00 (xfr#1390, ir-chk=2245/3643)
# Strawberry/train/images/fresa_397_jpg.rf.ee22f7aa5b01365eecb886fa12de3513.jpg
#          35.47K 100%   35.13kB/s    0:00:00 (xfr#1391, ir-chk=2244/3643)
# Strawberry/train/images/fresa_398_jpg.rf.50c5b220eb5e3e23bc262df317658fd2.jpg
#          47.02K 100%   45.51kB/s    0:00:01 (xfr#1392, ir-chk=2243/3643)
# Strawberry/train/images/fresa_398_jpg.rf.932f8038386abb77c2a138712c339ce2.jpg
#          48.26K 100%    2.00MB/s    0:00:00 (xfr#1393, ir-chk=2242/3643)
# Strawberry/train/images/fresa_398_jpg.rf.e2e79623d252c7db30256b35aa70714a.jpg
#          44.94K 100%  895.59kB/s    0:00:00 (xfr#1394, ir-chk=2241/3643)
# Strawberry/train/images/fresa_402_jpg.rf.1824762b872ea987d80eea5429235ee0.jpg
#          36.45K 100%  386.86kB/s    0:00:00 (xfr#1395, ir-chk=2240/3643)
# Strawberry/train/images/fresa_402_jpg.rf.bf819d787ff5138d464ae5de78d007c6.jpg
#          32.87K 100%  279.12kB/s    0:00:00 (xfr#1396, ir-chk=2239/3643)
# Strawberry/train/images/fresa_402_jpg.rf.f368f7768c477b224f3942447c1dd23a.jpg
#          34.06K 100%  242.81kB/s    0:00:00 (xfr#1397, ir-chk=2238/3643)
# Strawberry/train/images/fresa_403_jpg.rf.45b03055e0185f1fc0d9778c68a06885.jpg
#          24.50K 100%  173.36kB/s    0:00:00 (xfr#1398, ir-chk=2237/3643)
# Strawberry/train/images/fresa_403_jpg.rf.a55728d05c620b5d330faf16d4e8e345.jpg
#          25.28K 100%  152.42kB/s    0:00:00 (xfr#1399, ir-chk=2236/3643)
# Strawberry/train/images/fresa_403_jpg.rf.e71099777467ac43a9175e7e62033100.jpg
#          24.80K 100%  149.48kB/s    0:00:00 (xfr#1400, ir-chk=2235/3643)
# Strawberry/train/images/fresa_405_jpg.rf.3be85d5e9963a58115a11935fd90b032.jpg
#          30.86K 100%  144.87kB/s    0:00:00 (xfr#1401, ir-chk=2234/3643)
# Strawberry/train/images/fresa_405_jpg.rf.bfec3f6257e70d145347278343882bc2.jpg
#          30.73K 100%  144.27kB/s    0:00:00 (xfr#1402, ir-chk=2233/3643)
# Strawberry/train/images/fresa_405_jpg.rf.e6d5d8c9dba0cf8782d08a54789cca5c.jpg
#          30.68K 100%  144.04kB/s    0:00:00 (xfr#1403, ir-chk=2232/3643)
# Strawberry/train/images/fresa_407_jpg.rf.013113723c39cb66bcd97bdb4a10a0e8.jpg
#          38.81K 100%   65.34kB/s    0:00:00 (xfr#1404, ir-chk=2231/3643)
# Strawberry/train/images/fresa_407_jpg.rf.1311e50d9b78ee363e544630eb2fe95b.jpg
#          36.23K 100%   61.00kB/s    0:00:00 (xfr#1405, ir-chk=2230/3643)
# Strawberry/train/images/fresa_407_jpg.rf.a2e512280d905acef31042207d838c23.jpg
#          38.76K 100%   48.09kB/s    0:00:00 (xfr#1406, ir-chk=2229/3643)
# Strawberry/train/images/fresa_408_jpg.rf.0606cd0d9d8ecd3e50f8921e85b7143d.jpg
#          29.20K 100%   36.23kB/s    0:00:00 (xfr#1407, ir-chk=2228/3643)
# Strawberry/train/images/fresa_408_jpg.rf.8bbdc67c0c484d0a63551011f3e3e844.jpg
#          30.41K 100%   37.73kB/s    0:00:00 (xfr#1408, ir-chk=2227/3643)
# Strawberry/train/images/fresa_408_jpg.rf.d383033ca0310a6af0dd01a87376dd2c.jpg
#          29.30K 100%   33.91kB/s    0:00:00 (xfr#1409, ir-chk=2226/3643)
# Strawberry/train/images/fresa_409_jpg.rf.0dafcea912817b5816bf2b821f485652.jpg
#          23.00K 100%   26.62kB/s    0:00:00 (xfr#1410, ir-chk=2225/3643)
# Strawberry/train/images/fresa_409_jpg.rf.40199d76aecd9d38a11664046a389f25.jpg
#          25.38K 100%   22.27kB/s    0:00:01 (xfr#1411, ir-chk=2224/3643)
# Strawberry/train/images/fresa_409_jpg.rf.849763df446b1ecc82319ce26891a001.jpg
#          22.62K 100%   19.85kB/s    0:00:01 (xfr#1412, ir-chk=2223/3643)
# Strawberry/train/images/fresa_410_jpg.rf.40378ec6bc0e5766876e7e410e409da7.jpg
#          40.41K 100%   31.19kB/s    0:00:01 (xfr#1413, ir-chk=2222/3643)
# Strawberry/train/images/fresa_410_jpg.rf.a6674bb29636aa9e345ecf6e8a127b5f.jpg
#          39.95K 100%   38.10MB/s    0:00:00 (xfr#1414, ir-chk=2221/3643)
# Strawberry/train/images/fresa_410_jpg.rf.cd4fa0b0cdeb70432f58c08ba4984fce.jpg
#          39.36K 100%  610.18kB/s    0:00:00 (xfr#1415, ir-chk=2220/3643)
# Strawberry/train/images/fresa_411_jpg.rf.2be861ff1b10a992b5f1d6d3d5c7c917.jpg
#          42.11K 100%  472.69kB/s    0:00:00 (xfr#1416, ir-chk=2219/3643)
# Strawberry/train/images/fresa_411_jpg.rf.6ea5b27c35617a55d8955456d1a0f1dc.jpg
#          45.10K 100%  363.99kB/s    0:00:00 (xfr#1417, ir-chk=2218/3643)
# Strawberry/train/images/fresa_411_jpg.rf.8de3f74c5f32fb7408f094bd384550b0.jpg
#          43.09K 100%  204.30kB/s    0:00:00 (xfr#1418, ir-chk=2217/3643)
# Strawberry/train/images/fresa_412_jpg.rf.2d96da81e4333425e25805e5b1554270.jpg
#          46.83K 100%  160.45kB/s    0:00:00 (xfr#1419, ir-chk=2216/3643)
# Strawberry/train/images/fresa_412_jpg.rf.7eecc6b9291c0be3f3ad6fb9f70fd556.jpg
#          44.43K 100%  120.51kB/s    0:00:00 (xfr#1420, ir-chk=2215/3643)
# Strawberry/train/images/fresa_412_jpg.rf.839102e3983d74577ae38783560f4b48.jpg
#          45.67K 100%   92.73kB/s    0:00:00 (xfr#1421, ir-chk=2214/3643)
# Strawberry/train/images/fresa_414_jpg.rf.75f4490c0aa99ec3c1c492bd04567f48.jpg
#          31.71K 100%   51.87kB/s    0:00:00 (xfr#1422, ir-chk=2213/3643)
# Strawberry/train/images/fresa_414_jpg.rf.7c85390cea342357fd73b9e35fb9bdfa.jpg
#          34.32K 100%   46.42kB/s    0:00:00 (xfr#1423, ir-chk=2212/3643)
# Strawberry/train/images/fresa_414_jpg.rf.e51e21d7959d8b9fc494dd28e1bedac8.jpg
#          34.71K 100%   46.88kB/s    0:00:00 (xfr#1424, ir-chk=2211/3643)
# Strawberry/train/images/fresa_416_jpg.rf.3a25c0eaff07c1f87b58bea8acc4ddf2.jpg
#          46.00K 100%   53.48kB/s    0:00:00 (xfr#1425, ir-chk=2210/3643)
# Strawberry/train/images/fresa_416_jpg.rf.6dc1fc5583f2e0738fb50c8866455a39.jpg
#          46.24K 100%   53.75kB/s    0:00:00 (xfr#1426, ir-chk=2209/3643)
# Strawberry/train/images/fresa_416_jpg.rf.a85146a34d986f190dfe1d4a71e15cf8.jpg
#          45.83K 100%   50.75kB/s    0:00:00 (xfr#1427, ir-chk=2208/3643)
# Strawberry/train/images/fresa_418_jpg.rf.7754d4eacd59184458501e0d497b765a.jpg
#          29.55K 100%   30.37kB/s    0:00:00 (xfr#1428, ir-chk=2207/3643)
# Strawberry/train/images/fresa_418_jpg.rf.7cd814f23292e43096a5103998b353ef.jpg
#          31.16K 100%   32.03kB/s    0:00:00 (xfr#1429, ir-chk=2206/3643)
# Strawberry/train/images/fresa_418_jpg.rf.edb0f672163a6b1074f2527c20bd349b.jpg
#          30.35K 100%   28.89kB/s    0:00:01 (xfr#1430, ir-chk=2205/3643)
# Strawberry/train/images/fresa_419_jpg.rf.02ddedc852bdf199c0d33d9ac580e988.jpg
#          30.70K 100%   29.22kB/s    0:00:01 (xfr#1431, ir-chk=2204/3643)
# Strawberry/train/images/fresa_419_jpg.rf.70de1e69f488a7ebff94e98a5d10ec50.jpg
#          27.00K 100%   22.61kB/s    0:00:01 (xfr#1432, ir-chk=2203/3643)
# Strawberry/train/images/fresa_419_jpg.rf.f0322f1ee3834d1724c4ffd92ffc1bbd.jpg
#          27.96K 100%   23.42kB/s    0:00:01 (xfr#1433, ir-chk=2202/3643)
# Strawberry/train/images/fresa_420_jpg.rf.4a3b4a82964d8b5da90899b28c891fc3.jpg
#          36.28K 100%   26.34kB/s    0:00:01 (xfr#1434, ir-chk=2201/3643)
# Strawberry/train/images/fresa_420_jpg.rf.7c224f482269a054138aff1945dceb83.jpg
#          36.34K 100%  381.56kB/s    0:00:00 (xfr#1435, ir-chk=2200/3643)
# Strawberry/train/images/fresa_420_jpg.rf.99dae900e1c208ff5d5826d51b623e61.jpg
#          36.01K 100%  374.14kB/s    0:00:00 (xfr#1436, ir-chk=2199/3643)
# Strawberry/train/images/fresa_421_jpg.rf.130db4c47666832cb4ba7b7325bcb30f.jpg
#          27.21K 100%  282.67kB/s    0:00:00 (xfr#1437, ir-chk=2198/3643)
# Strawberry/train/images/fresa_421_jpg.rf.99da662479a285eab7f4321a4cb0da85.jpg
#          27.24K 100%  167.33kB/s    0:00:00 (xfr#1438, ir-chk=2197/3643)
# Strawberry/train/images/fresa_421_jpg.rf.d531c771d09af384e3188f6e2995a08e.jpg
#          29.64K 100%  182.06kB/s    0:00:00 (xfr#1439, ir-chk=2196/3643)
# Strawberry/train/images/fresa_422_jpg.rf.1fd16d9599643267d261609f19b2e7b9.jpg
#          52.55K 100%  234.33kB/s    0:00:00 (xfr#1440, ir-chk=2195/3643)
# Strawberry/train/images/fresa_422_jpg.rf.5a64a3009d42f6e83daff750450cdb7b.jpg
#          52.54K 100%   95.37kB/s    0:00:00 (xfr#1441, ir-chk=2194/3643)
# Strawberry/train/images/fresa_422_jpg.rf.b81677567ba31aba1522c65ff10c137f.jpg
#          46.29K 100%   71.99kB/s    0:00:00 (xfr#1442, ir-chk=2193/3643)
# Strawberry/train/images/fresa_424_jpg.rf.659a70c80b68535deefe64155816a3b5.jpg
#          33.60K 100%   43.81kB/s    0:00:00 (xfr#1443, ir-chk=2192/3643)
# Strawberry/train/images/fresa_424_jpg.rf.aabffd198583a02fba08f8bbdde94e97.jpg
#          35.37K 100%   46.12kB/s    0:00:00 (xfr#1444, ir-chk=2191/3643)
# Strawberry/train/images/fresa_424_jpg.rf.b418505807f2991a3d36e32fcb61ca55.jpg
#          34.26K 100%   35.60kB/s    0:00:00 (xfr#1445, ir-chk=2190/3643)
# Strawberry/train/images/fresa_425_jpg.rf.08383f1d292b29805e31fa30ea1e51d9.jpg
#          28.63K 100%   29.74kB/s    0:00:00 (xfr#1446, ir-chk=2189/3643)
# Strawberry/train/images/fresa_425_jpg.rf.808762417a36f8733bb1fdc6bbd0194f.jpg
#          27.38K 100%   25.64kB/s    0:00:01 (xfr#1447, ir-chk=2188/3643)
# Strawberry/train/images/fresa_425_jpg.rf.f939d20832894e83792a54a3a97e8244.jpg
#          28.14K 100%   26.35kB/s    0:00:01 (xfr#1448, ir-chk=2187/3643)
# Strawberry/train/images/fresa_426_jpg.rf.253829f7deb5d2848be1ad553291a962.jpg
#          34.54K 100%   27.33kB/s    0:00:01 (xfr#1449, ir-chk=2186/3643)
# Strawberry/train/images/fresa_426_jpg.rf.2bf0a642c5d32f20f09560d685968e72.jpg
#          36.38K 100%  273.26kB/s    0:00:00 (xfr#1450, ir-chk=2185/3643)
# Strawberry/train/images/fresa_426_jpg.rf.88ba0b93601a22fdd5fdc282412754f9.jpg
#          36.60K 100%  274.91kB/s    0:00:00 (xfr#1451, ir-chk=2184/3643)
# Strawberry/train/images/fresa_428_jpg.rf.2796fdf9f824a1a25a8bfd48538d0b14.jpg
#          27.54K 100%  206.91kB/s    0:00:00 (xfr#1452, ir-chk=2183/3643)
# Strawberry/train/images/fresa_428_jpg.rf.7d5b7a663e063cf3d2f0e06306ad4d33.jpg
#          26.66K 100%  152.25kB/s    0:00:00 (xfr#1453, ir-chk=2182/3643)
# Strawberry/train/images/fresa_428_jpg.rf.a877f08a02ff8e6d453f6d2756af52e4.jpg
#          27.55K 100%  157.32kB/s    0:00:00 (xfr#1454, ir-chk=2181/3643)
# Strawberry/train/images/fresa_429_jpg.rf.086c1bc2fd94ba9b7866b25788ba2950.jpg
#          40.61K 100%  125.50kB/s    0:00:00 (xfr#1455, ir-chk=2180/3643)
# Strawberry/train/images/fresa_429_jpg.rf.4bd9c45acec399fa4fe0dea302ea5fbd.jpg
#          36.22K 100%   52.32kB/s    0:00:00 (xfr#1456, ir-chk=2179/3643)
# Strawberry/train/images/fresa_429_jpg.rf.f4eb75f84b7b2d3844943cbf83423b01.jpg
#          39.77K 100%   57.45kB/s    0:00:00 (xfr#1457, ir-chk=2178/3643)
# Strawberry/train/images/fresa_432_jpg.rf.2ade0aa2bbc6b1153ac1e9dce8ff1fa4.jpg
#          32.70K 100%   43.56kB/s    0:00:00 (xfr#1458, ir-chk=2177/3643)
# Strawberry/train/images/fresa_432_jpg.rf.2f907cd2681233eac527481fe2ee16f0.jpg
#          33.03K 100%   39.34kB/s    0:00:00 (xfr#1459, ir-chk=2176/3643)
# Strawberry/train/images/fresa_432_jpg.rf.d576dddce84b7f38db70d4bd49b9893a.jpg
#          33.42K 100%   39.81kB/s    0:00:00 (xfr#1460, ir-chk=2175/3643)
# Strawberry/train/images/fresa_434_jpg.rf.5d789b983831dd5cc92243946fe03843.jpg
#          32.78K 100%   28.46kB/s    0:00:01 (xfr#1461, ir-chk=2174/3643)
# Strawberry/train/images/fresa_434_jpg.rf.6b03873caa6ff53f4e04ffe1975ab9d3.jpg
#          33.06K 100%   31.53MB/s    0:00:00 (xfr#1462, ir-chk=2173/3643)
# Strawberry/train/images/fresa_434_jpg.rf.a2df3bd44627a772163b2c8ccd32a3c2.jpg
#          33.28K 100%  306.65kB/s    0:00:00 (xfr#1463, ir-chk=2172/3643)
# Strawberry/train/images/fresa_435_jpg.rf.4f2697d3fdf5dc5b421ca4512b53c8a1.jpg
#          51.41K 100%  374.65kB/s    0:00:00 (xfr#1464, ir-chk=2171/3643)
# Strawberry/train/images/fresa_435_jpg.rf.682c281c7a5f4968db22e6d42f09cea7.jpg
#          50.58K 100%  308.72kB/s    0:00:00 (xfr#1465, ir-chk=2170/3643)
# Strawberry/train/images/fresa_435_jpg.rf.b76f486a4de7d19b331a24131b8376c5.jpg
#          51.23K 100%  176.80kB/s    0:00:00 (xfr#1466, ir-chk=2169/3643)
# Strawberry/train/images/fresa_436_jpg.rf.06ecd424a1fe119accc923d841d9a75d.jpg
#          22.32K 100%   59.89kB/s    0:00:00 (xfr#1467, ir-chk=2168/3643)
# Strawberry/train/images/fresa_436_jpg.rf.0b1c49a7fe343fa9b1c4866cad585d92.jpg
#          21.84K 100%   58.60kB/s    0:00:00 (xfr#1468, ir-chk=2167/3643)
# Strawberry/train/images/fresa_436_jpg.rf.723a45f6a910a870ccbebe0fb0cadc9a.jpg
#          25.36K 100%   54.55kB/s    0:00:00 (xfr#1469, ir-chk=2166/3643)
# Strawberry/train/images/fresa_437_jpg.rf.2c515eb7290bcc12da26500b5d3e5538.jpg
#          26.15K 100%   56.25kB/s    0:00:00 (xfr#1470, ir-chk=2165/3643)
# Strawberry/train/images/fresa_437_jpg.rf.5b5d277d84a1aa00f9187aeeffad0478.jpg
#          25.25K 100%   54.30kB/s    0:00:00 (xfr#1471, ir-chk=2164/3643)
# Strawberry/train/images/fresa_437_jpg.rf.c8bef04aec74f52180a38a8939b3828c.jpg
#          27.82K 100%   59.83kB/s    0:00:00 (xfr#1472, ir-chk=2163/3643)
# Strawberry/train/images/fresa_439_jpg.rf.157335acf0a1a09e81e3417788dbd875.jpg
#          33.12K 100%   44.06kB/s    0:00:00 (xfr#1473, ir-chk=2162/3643)
# Strawberry/train/images/fresa_439_jpg.rf.59a81cd4225b340149f9b5315a264e3a.jpg
#          32.14K 100%   42.77kB/s    0:00:00 (xfr#1474, ir-chk=2161/3643)
# Strawberry/train/images/fresa_439_jpg.rf.696b8cf0cb9f3c4d616d6fae57c3b68e.jpg
#          33.84K 100%   37.38kB/s    0:00:00 (xfr#1475, ir-chk=2160/3643)
# Strawberry/train/images/fresa_440_jpg.rf.7a205e818bccfbbc1890829f048d8417.jpg
#          45.73K 100%   44.84kB/s    0:00:00 (xfr#1476, ir-chk=2159/3643)
# Strawberry/train/images/fresa_440_jpg.rf.8462a4db80f4f622f96650d9f62fa944.jpg
#          42.85K 100%   42.02kB/s    0:00:00 (xfr#1477, ir-chk=2158/3643)
# Strawberry/train/images/fresa_440_jpg.rf.afe00d58c4ac15f0e49096eb90955032.jpg
#          45.12K 100%   37.72kB/s    0:00:01 (xfr#1478, ir-chk=2157/3643)
# Strawberry/train/images/fresa_442_jpg.rf.1bed4714da6193517964322adb6939f5.jpg
#          38.47K 100%    1.53MB/s    0:00:00 (xfr#1479, ir-chk=2156/3643)
# Strawberry/train/images/fresa_442_jpg.rf.9a11cd6d16840ded46e48f9a6b1a2071.jpg
#          43.35K 100%  846.76kB/s    0:00:00 (xfr#1480, ir-chk=2155/3643)
# Strawberry/train/images/fresa_442_jpg.rf.9bc8366d1f15f8f3ca45265a0615b4b6.jpg
#          42.13K 100%  351.61kB/s    0:00:00 (xfr#1481, ir-chk=2154/3643)
# Strawberry/train/images/fresa_443_jpg.rf.035e43e534da3c7ef5d09d074166569f.jpg
#          27.23K 100%  184.66kB/s    0:00:00 (xfr#1482, ir-chk=2153/3643)
# Strawberry/train/images/fresa_443_jpg.rf.22388e8369ba1b6805b3cd29e09b484c.jpg
#          27.17K 100%  184.26kB/s    0:00:00 (xfr#1483, ir-chk=2152/3643)
# Strawberry/train/images/fresa_443_jpg.rf.befdad56bfbbdcd7a46961f5ddaa951d.jpg
#          27.50K 100%  120.41kB/s    0:00:00 (xfr#1484, ir-chk=2151/3643)
# Strawberry/train/images/fresa_444_jpg.rf.35b3bb4ee070652627fc8263c91235fa.jpg
#          35.46K 100%  155.30kB/s    0:00:00 (xfr#1485, ir-chk=2150/3643)
# Strawberry/train/images/fresa_444_jpg.rf.73bfa5516a5d383a629e1a15a46a908f.jpg
#          36.14K 100%   85.25kB/s    0:00:00 (xfr#1486, ir-chk=2149/3643)
# Strawberry/train/images/fresa_444_jpg.rf.828e275ef1e78926f3658480ce864ca7.jpg
#          35.42K 100%   57.85kB/s    0:00:00 (xfr#1487, ir-chk=2148/3643)
# Strawberry/train/images/fresa_445_jpg.rf.0092113049b3317f6d673973eb370e1b.jpg
#          36.88K 100%   60.23kB/s    0:00:00 (xfr#1488, ir-chk=2147/3643)
# Strawberry/train/images/fresa_445_jpg.rf.54f907f00fa527cfc808e8d9412d9f38.jpg
#          35.62K 100%   52.00kB/s    0:00:00 (xfr#1489, ir-chk=2146/3643)
# Strawberry/train/images/fresa_445_jpg.rf.e1417d11fc88cabb7befc54a1970b269.jpg
#          38.12K 100%   47.06kB/s    0:00:00 (xfr#1490, ir-chk=2145/3643)
# Strawberry/train/images/fresa_448_jpg.rf.0f22f6be80c11c1a69740da1a0794d75.jpg
#          20.87K 100%   25.77kB/s    0:00:00 (xfr#1491, ir-chk=2144/3643)
# Strawberry/train/images/fresa_448_jpg.rf.2b1a8e5c286077358c61d60f534de2c0.jpg
#          17.45K 100%   19.41kB/s    0:00:00 (xfr#1492, ir-chk=2143/3643)
# Strawberry/train/images/fresa_448_jpg.rf.fef0c4c04e9a05e5f5e06b68f489de26.jpg
#          19.05K 100%   21.19kB/s    0:00:00 (xfr#1493, ir-chk=2142/3643)
# Strawberry/train/images/fresa_449_jpg.rf.044c511b251286a5c57f85d0d7590e47.jpg
#          51.91K 100%   46.85kB/s    0:00:01 (xfr#1494, ir-chk=2141/3643)
# Strawberry/train/images/fresa_449_jpg.rf.389a78f90ad49195c239d1052d6ad718.jpg
#          48.38K 100%   46.14MB/s    0:00:00 (xfr#1495, ir-chk=2140/3643)
# Strawberry/train/images/fresa_449_jpg.rf.e1fad67d6b0a8f10053a170e65c2abb5.jpg
#          49.80K 100%  333.07kB/s    0:00:00 (xfr#1496, ir-chk=2139/3643)
# Strawberry/train/images/fresa_450_jpg.rf.6ac8b293b0f9e0db315a54f99f4e3567.jpg
#          45.88K 100%  306.89kB/s    0:00:00 (xfr#1497, ir-chk=2138/3643)
# Strawberry/train/images/fresa_450_jpg.rf.74602fc7d9c6c5b5a4de87acd7be88fa.jpg
#          45.95K 100%  191.77kB/s    0:00:00 (xfr#1498, ir-chk=2137/3643)
# Strawberry/train/images/fresa_450_jpg.rf.e9d09137352cc563c0a22d24d29d1374.jpg
#          48.10K 100%  129.77kB/s    0:00:00 (xfr#1499, ir-chk=2136/3643)
# Strawberry/train/images/fresa_451_jpg.rf.447cac5ad59046bad9faa33d47733b02.jpg
#          36.94K 100%   82.36kB/s    0:00:00 (xfr#1500, ir-chk=2135/3643)
# Strawberry/train/images/fresa_451_jpg.rf.673ebbf249043da3cd844d516d1aaa20.jpg
#          35.44K 100%   68.12kB/s    0:00:00 (xfr#1501, ir-chk=2134/3643)
# Strawberry/train/images/fresa_451_jpg.rf.bfa216360c27abc809ca70397fb30b00.jpg
#          29.66K 100%   56.90kB/s    0:00:00 (xfr#1502, ir-chk=2133/3643)
# Strawberry/train/images/fresa_452_jpg.rf.21414f0d0e19a0e4b5847939b30c2dd5.jpg
#          36.10K 100%   63.18kB/s    0:00:00 (xfr#1503, ir-chk=2132/3643)
# Strawberry/train/images/fresa_452_jpg.rf.95ad35a13cca30129d28a1c5303ec00e.jpg
#          33.41K 100%   52.79kB/s    0:00:00 (xfr#1504, ir-chk=2131/3643)
# Strawberry/train/images/fresa_452_jpg.rf.db0fcca79743f0f8f482ca2a12066e0a.jpg
#          36.95K 100%   58.39kB/s    0:00:00 (xfr#1505, ir-chk=2130/3643)
# Strawberry/train/images/fresa_453_jpg.rf.01be936c1817a60d9014ec99c14f159d.jpg
#          38.05K 100%   54.97kB/s    0:00:00 (xfr#1506, ir-chk=2129/3643)
# Strawberry/train/images/fresa_453_jpg.rf.a986743a613202b47c31989c2cb54946.jpg
#          37.58K 100%   51.04kB/s    0:00:00 (xfr#1507, ir-chk=2128/3643)
# Strawberry/train/images/fresa_453_jpg.rf.f140dc59361b603dd9bd1a2199cd6f63.jpg
#          39.35K 100%   51.04kB/s    0:00:00 (xfr#1508, ir-chk=2127/3643)
# Strawberry/train/images/fresa_454_jpg.rf.3d259651d678fb6c65ad3e2617a47fc5.jpg
#          34.79K 100%   43.34kB/s    0:00:00 (xfr#1509, ir-chk=2126/3643)
# Strawberry/train/images/fresa_454_jpg.rf.72fabd020757387ba85db6d3b1c63bc7.jpg
#          34.13K 100%   40.55kB/s    0:00:00 (xfr#1510, ir-chk=2125/3643)
# Strawberry/train/images/fresa_454_jpg.rf.a0f25c8d0575d1da13b13ab4bbd7685c.jpg
#          31.60K 100%   36.22kB/s    0:00:00 (xfr#1511, ir-chk=2124/3643)
# Strawberry/train/images/fresa_455_jpg.rf.1f925c2e82a8cdc5225382f912bf2637.jpg
#          43.13K 100%   47.92kB/s    0:00:00 (xfr#1512, ir-chk=2123/3643)
# Strawberry/train/images/fresa_455_jpg.rf.a43401743ca95e49f23436f7696390ef.jpg
#          40.16K 100%   44.62kB/s    0:00:00 (xfr#1513, ir-chk=2122/3643)
# Strawberry/train/images/fresa_455_jpg.rf.e8cddf5c4086418eb86c5d8605503fe1.jpg
#          44.56K 100%   45.19kB/s    0:00:00 (xfr#1514, ir-chk=2121/3643)
# Strawberry/train/images/fresa_457_jpg.rf.228a9c031e90b84339a1faa8cf2d4c99.jpg
#          29.06K 100%   28.16kB/s    0:00:01 (xfr#1515, ir-chk=2120/3643)
# Strawberry/train/images/fresa_457_jpg.rf.25a0c8daea4474c12ad8e9f73934e9ad.jpg
#          28.22K 100%   27.34kB/s    0:00:01 (xfr#1516, ir-chk=2119/3643)
# Strawberry/train/images/fresa_457_jpg.rf.a9c2d8bffd5ccceb5ae07bde3ecc1b93.jpg
#          27.95K 100%   27.08kB/s    0:00:01 (xfr#1517, ir-chk=2118/3643)
# Strawberry/train/images/fresa_458_jpg.rf.75f63620a1696ace207e3101f2f74c4a.jpg
#          39.72K 100%   29.66kB/s    0:00:01 (xfr#1518, ir-chk=2117/3643)
# Strawberry/train/images/fresa_458_jpg.rf.7621fe5820596b553710ac261379aa9a.jpg
#          39.44K 100%   37.61MB/s    0:00:00 (xfr#1519, ir-chk=2116/3643)
# Strawberry/train/images/fresa_458_jpg.rf.ca610d954b82d562eb774e65b0f05a6b.jpg
#          41.30K 100%  640.22kB/s    0:00:00 (xfr#1520, ir-chk=2115/3643)
# Strawberry/train/images/fresa_459_jpg.rf.25ba10d57264f0b6af774c41f1ae5ed4.jpg
#          38.64K 100%  589.58kB/s    0:00:00 (xfr#1521, ir-chk=2114/3643)
# Strawberry/train/images/fresa_459_jpg.rf.41e977a5bb9ce2d83148b4c0dadc2797.jpg
#          43.28K 100%  464.44kB/s    0:00:00 (xfr#1522, ir-chk=2113/3643)
# Strawberry/train/images/fresa_459_jpg.rf.75c4ca1a449cafd6b5a118b3ac11e270.jpg
#          39.66K 100%  251.50kB/s    0:00:00 (xfr#1523, ir-chk=2112/3643)
# Strawberry/train/images/fresa_460_jpg.rf.4c5b7ecd1318ea3491c5f72798cba49a.jpg
#          37.56K 100%  144.40kB/s    0:00:00 (xfr#1524, ir-chk=2111/3643)
# Strawberry/train/images/fresa_460_jpg.rf.507c66c2ac99ed1d0f177f3c72c31da2.jpg
#          32.84K 100%   94.04kB/s    0:00:00 (xfr#1525, ir-chk=2110/3643)
# Strawberry/train/images/fresa_460_jpg.rf.a54156a4b04f8dbd5747185a442463cd.jpg
#          32.77K 100%   65.99kB/s    0:00:00 (xfr#1526, ir-chk=2109/3643)
# Strawberry/train/images/fresa_461_jpg.rf.40e2ca229f87191562a218ee6f73b247.jpg
#          29.75K 100%   59.89kB/s    0:00:00 (xfr#1527, ir-chk=2108/3643)
# Strawberry/train/images/fresa_461_jpg.rf.9eabadf63b68fbb31bf995cdc6e97d10.jpg
#          27.88K 100%   52.66kB/s    0:00:00 (xfr#1528, ir-chk=2107/3643)
# Strawberry/train/images/fresa_461_jpg.rf.fb03d20b5d47e767b0c8429cbbc108c5.jpg
#          28.56K 100%   53.95kB/s    0:00:00 (xfr#1529, ir-chk=2106/3643)
# Strawberry/train/images/fresa_462_jpg.rf.0a629a7168fb4b1cdb9a902af77aa5e1.jpg
#          38.96K 100%   66.52kB/s    0:00:00 (xfr#1530, ir-chk=2105/3643)
# Strawberry/train/images/fresa_462_jpg.rf.169cfef0a70fcf3ae26e3f605a4dff7f.jpg
#          34.28K 100%   45.99kB/s    0:00:00 (xfr#1531, ir-chk=2104/3643)
# Strawberry/train/images/fresa_462_jpg.rf.2440a1f1c089de3884248d9f0f9f6eb7.jpg
#          33.45K 100%   44.87kB/s    0:00:00 (xfr#1532, ir-chk=2103/3643)
# Strawberry/train/images/fresa_463_jpg.rf.1ce9af251bf9a80bae1bec03bd4acf25.jpg
#          21.50K 100%   28.84kB/s    0:00:00 (xfr#1533, ir-chk=2102/3643)
# Strawberry/train/images/fresa_463_jpg.rf.72a73ebc1c85bb814e8178afac445c07.jpg
#          22.67K 100%   26.17kB/s    0:00:00 (xfr#1534, ir-chk=2101/3643)
# Strawberry/train/images/fresa_463_jpg.rf.e3855514a95adb4754a37f8a19c42dd8.jpg
#          23.99K 100%   27.69kB/s    0:00:00 (xfr#1535, ir-chk=2100/3643)
# Strawberry/train/images/fresa_464_jpg.rf.21fdcd781922d977ede1349c16617201.jpg
#          34.48K 100%   34.46kB/s    0:00:00 (xfr#1536, ir-chk=2099/3643)
# Strawberry/train/images/fresa_464_jpg.rf.75ff9708c510fd5dd4a591e7d695c7a2.jpg
#          34.82K 100%   34.80kB/s    0:00:00 (xfr#1537, ir-chk=2098/3643)
# Strawberry/train/images/fresa_464_jpg.rf.b7289c1e5cdb1d6a37bb67283979968d.jpg
#          34.95K 100%   32.23kB/s    0:00:01 (xfr#1538, ir-chk=2097/3643)
# Strawberry/train/images/fresa_466_jpg.rf.21870cedf1372f04ee72b10e432403ef.jpg
#          39.54K 100%  521.77kB/s    0:00:00 (xfr#1539, ir-chk=2096/3643)
# Strawberry/train/images/fresa_466_jpg.rf.b0ad49d214e56e0e45a6352518993952.jpg
#          47.28K 100%  279.83kB/s    0:00:00 (xfr#1540, ir-chk=2095/3643)
# Strawberry/train/images/fresa_466_jpg.rf.e8eb3915651b01333cf2d752b188213b.jpg
#          48.61K 100%  192.97kB/s    0:00:00 (xfr#1541, ir-chk=2094/3643)
# Strawberry/train/images/fresa_468_jpg.rf.18a0ba00595f5279509980dce3a1a328.jpg
#          47.56K 100%  137.00kB/s    0:00:00 (xfr#1542, ir-chk=2093/3643)
# Strawberry/train/images/fresa_468_jpg.rf.4dc4fc11b03be9fbdf39eec56e95ee16.jpg
#          47.18K 100%  125.21kB/s    0:00:00 (xfr#1543, ir-chk=2092/3643)
# Strawberry/train/images/fresa_468_jpg.rf.b55d9ddc562132d68d253dc2a1cdac4f.jpg
#          43.11K 100%  106.84kB/s    0:00:00 (xfr#1544, ir-chk=2091/3643)
# Strawberry/train/images/fresa_469_jpg.rf.035b31301f9d07e6d730f759b0350d84.jpg
#          45.02K 100%  105.17kB/s    0:00:00 (xfr#1545, ir-chk=2090/3643)
# Strawberry/train/images/fresa_469_jpg.rf.4a145e77c33c2bf4ba4f25c688201f3a.jpg
#          40.26K 100%   88.75kB/s    0:00:00 (xfr#1546, ir-chk=2089/3643)
# Strawberry/train/images/fresa_469_jpg.rf.cf434570e81bcfbfac5aa324de51c184.jpg
#          37.37K 100%   77.81kB/s    0:00:00 (xfr#1547, ir-chk=2088/3643)
# Strawberry/train/images/fresa_470_jpg.rf.37e26a3894f9496950888e1258f93510.jpg
#          38.34K 100%   75.63kB/s    0:00:00 (xfr#1548, ir-chk=2087/3643)
# Strawberry/train/images/fresa_470_jpg.rf.4251ef9f4f1356f2ebd3021867192a4b.jpg
#          40.35K 100%   75.49kB/s    0:00:00 (xfr#1549, ir-chk=2086/3643)
# Strawberry/train/images/fresa_470_jpg.rf.975062d9d4983b7725c9dc039ef69761.jpg
#          36.72K 100%   64.37kB/s    0:00:00 (xfr#1550, ir-chk=2085/3643)
# Strawberry/train/images/fresa_471_jpg.rf.1b406f5b987067657fc769d47ebca16d.jpg
#          31.93K 100%   51.96kB/s    0:00:00 (xfr#1551, ir-chk=2084/3643)
# Strawberry/train/images/fresa_471_jpg.rf.809018b53ec0bb9f59d4e8f8fa675b4d.jpg
#          33.32K 100%   54.23kB/s    0:00:00 (xfr#1552, ir-chk=2083/3643)
# Strawberry/train/images/fresa_471_jpg.rf.814cd293179f6091a3f0819cfa1aecf5.jpg
#          32.69K 100%   51.00kB/s    0:00:00 (xfr#1553, ir-chk=2082/3643)
# Strawberry/train/images/fresa_474_jpg.rf.31a42222429465f7558b6758f9735b2c.jpg
#          35.91K 100%   49.68kB/s    0:00:00 (xfr#1554, ir-chk=2081/3643)
# Strawberry/train/images/fresa_474_jpg.rf.a6f31eb44a6186d2cf61532796cc62c1.jpg
#          29.55K 100%   40.88kB/s    0:00:00 (xfr#1555, ir-chk=2080/3643)
# Strawberry/train/images/fresa_474_jpg.rf.b606a5334621b235bf3c793ba0d2f6a8.jpg
#          37.41K 100%   45.38kB/s    0:00:00 (xfr#1556, ir-chk=2079/3643)
# Strawberry/train/images/fresa_476_jpg.rf.6b8b2aae0b2cd5e969367fb43e609709.jpg
#          44.47K 100%   53.95kB/s    0:00:00 (xfr#1557, ir-chk=2078/3643)
# Strawberry/train/images/fresa_476_jpg.rf.b303296e0fa3b6906ec3199742f3d801.jpg
#          47.59K 100%   51.93kB/s    0:00:00 (xfr#1558, ir-chk=2077/3643)
# Strawberry/train/images/fresa_476_jpg.rf.e4c06668283d6fdb9b67078629ba899a.jpg
#          45.99K 100%   45.05kB/s    0:00:00 (xfr#1559, ir-chk=2076/3643)
# Strawberry/train/images/fresa_477_jpg.rf.4ea7239ffbcaacf8009cc205f2883099.jpg
#          41.53K 100%   37.14kB/s    0:00:01 (xfr#1560, ir-chk=2075/3643)
# Strawberry/train/images/fresa_477_jpg.rf.56d1b6bd228a7ad28575086753fde0f0.jpg
#          32.88K 100%    1.05MB/s    0:00:00 (xfr#1561, ir-chk=2074/3643)
# Strawberry/train/images/fresa_477_jpg.rf.c82bb424597e21cb7322ca9d07ae84d0.jpg
#          38.90K 100%  520.33kB/s    0:00:00 (xfr#1562, ir-chk=2073/3643)
# Strawberry/train/images/fresa_478_jpg.rf.565dd56b88ca1c0a803152777293cc0c.jpg
#          43.23K 100%  322.27kB/s    0:00:00 (xfr#1563, ir-chk=2072/3643)
# Strawberry/train/images/fresa_478_jpg.rf.57332ec910b1d4cf1ba6f673ab6447fa.jpg
#          44.09K 100%  183.24kB/s    0:00:00 (xfr#1564, ir-chk=2071/3643)
# Strawberry/train/images/fresa_478_jpg.rf.71403dab9872ddf41b324a77a8d5093a.jpg
#          45.40K 100%  127.77kB/s    0:00:00 (xfr#1565, ir-chk=2070/3643)
# Strawberry/train/images/fresa_480_jpg.rf.05ac128c1416495b7d5ec34faff96d1d.jpg
#          41.69K 100%   91.90kB/s    0:00:00 (xfr#1566, ir-chk=2069/3643)
# Strawberry/train/images/fresa_480_jpg.rf.217f753637cbc1204cae2f4f4dac893f.jpg
#          46.90K 100%   92.72kB/s    0:00:00 (xfr#1567, ir-chk=2068/3643)
# Strawberry/train/images/fresa_480_jpg.rf.f8cae429bf90abd5000366c37f0a9f4a.jpg
#          44.62K 100%   83.79kB/s    0:00:00 (xfr#1568, ir-chk=2067/3643)
# Strawberry/train/images/fresa_482_jpg.rf.968657f961235b11ccd5dc875927747b.jpg
#          42.55K 100%   72.64kB/s    0:00:00 (xfr#1569, ir-chk=2066/3643)
# Strawberry/train/images/fresa_482_jpg.rf.c7eb73d4c1eebf0175c27e01cbd921af.jpg
#          41.54K 100%   60.37kB/s    0:00:00 (xfr#1570, ir-chk=2065/3643)
# Strawberry/train/images/fresa_482_jpg.rf.ea1d3e253c31deb31f4a754c28371d0f.jpg
#          43.66K 100%   54.59kB/s    0:00:00 (xfr#1571, ir-chk=2064/3643)
# Strawberry/train/images/fresa_483_jpg.rf.118f614b75476a6780226e0e40dabc36.jpg
#          37.28K 100%   41.71kB/s    0:00:00 (xfr#1572, ir-chk=2063/3643)
# Strawberry/train/images/fresa_483_jpg.rf.8a0cdcbc125afe4e8148f59eab9b768f.jpg
#          38.32K 100%   38.11kB/s    0:00:00 (xfr#1573, ir-chk=2062/3643)
# Strawberry/train/images/fresa_483_jpg.rf.bb5d18f26c7a799cb78ba68cf5dcd5f3.jpg
#          37.96K 100%   34.48kB/s    0:00:01 (xfr#1574, ir-chk=2061/3643)
# Strawberry/train/images/fresa_484_jpg.rf.0556dd06b4f8278dd9d7097b05b37630.jpg
#          28.28K 100%  242.24kB/s    0:00:00 (xfr#1575, ir-chk=2060/3643)
# Strawberry/train/images/fresa_484_jpg.rf.4d629d96a0c1eea9651d63cd57a0d689.jpg
#          27.73K 100%  237.55kB/s    0:00:00 (xfr#1576, ir-chk=2059/3643)
# Strawberry/train/images/fresa_484_jpg.rf.b4030a3fa70882a9a55cb83273d5a1c7.jpg
#          28.28K 100%  154.29kB/s    0:00:00 (xfr#1577, ir-chk=2058/3643)
# Strawberry/train/images/fresa_486_jpg.rf.22ba9784585433b586651b96c590d8ae.jpg
#          40.50K 100%  120.94kB/s    0:00:00 (xfr#1578, ir-chk=2057/3643)
# Strawberry/train/images/fresa_486_jpg.rf.b3581206225845dc987f704b89340fce.jpg
#          41.48K 100%  123.87kB/s    0:00:00 (xfr#1579, ir-chk=2056/3643)
# Strawberry/train/images/fresa_486_jpg.rf.cea01046e2d9cf118b3be4a83285a9e7.jpg
#          34.30K 100%   66.07kB/s    0:00:00 (xfr#1580, ir-chk=2055/3643)
# Strawberry/train/images/fresa_487_jpg.rf.0d5bb1b506bc395612160e18967cd8e3.jpg
#          37.83K 100%   72.86kB/s    0:00:00 (xfr#1581, ir-chk=2054/3643)
# Strawberry/train/images/fresa_487_jpg.rf.5c4fa39009744d4b2591459e27a9cfcc.jpg
#          41.00K 100%   74.70kB/s    0:00:00 (xfr#1582, ir-chk=2053/3643)
# Strawberry/train/images/fresa_487_jpg.rf.d8831515a27e12e0d8ac48d152254cf2.jpg
#          38.68K 100%   66.85kB/s    0:00:00 (xfr#1583, ir-chk=2052/3643)
# Strawberry/train/images/fresa_489_jpg.rf.0d226563a8c44d24a79d624c88709b51.jpg
#          44.44K 100%   72.94kB/s    0:00:00 (xfr#1584, ir-chk=2051/3643)
# Strawberry/train/images/fresa_489_jpg.rf.5705144b5ea38f22497353dbfbe02bae.jpg
#          43.07K 100%   62.31kB/s    0:00:00 (xfr#1585, ir-chk=2050/3643)
# Strawberry/train/images/fresa_489_jpg.rf.dfdae46b13e9f9d9aa49d6cb0aab45ae.jpg
#          45.34K 100%   62.36kB/s    0:00:00 (xfr#1586, ir-chk=2049/3643)
# Strawberry/train/images/fresa_492_jpg.rf.5e6f55ee0fb78e1da5bf41009b63880d.jpg
#          42.52K 100%   56.26kB/s    0:00:00 (xfr#1587, ir-chk=2048/3643)
# Strawberry/train/images/fresa_492_jpg.rf.97105a810ec321deb421a8b235fdf0f0.jpg
#          46.22K 100%   59.08kB/s    0:00:00 (xfr#1588, ir-chk=2047/3643)
# Strawberry/train/images/fresa_492_jpg.rf.a9cef0839be1395f315e6dab5e3cb9fc.jpg
#          47.18K 100%   57.45kB/s    0:00:00 (xfr#1589, ir-chk=2046/3643)
# Strawberry/train/images/fresa_493_jpg.rf.388224117a463db2d21f13a82931abcf.jpg
#          50.11K 100%   58.96kB/s    0:00:00 (xfr#1590, ir-chk=2045/3643)
# Strawberry/train/images/fresa_493_jpg.rf.a53ce1f34fddbbfa5c2dbcd3382cff03.jpg
#          49.50K 100%   56.40kB/s    0:00:00 (xfr#1591, ir-chk=2044/3643)
# Strawberry/train/images/fresa_493_jpg.rf.b3eed0e964f72a0fdcdf1b81ce0bbdc6.jpg
#          49.14K 100%   54.29kB/s    0:00:00 (xfr#1592, ir-chk=2043/3643)
# Strawberry/train/images/fresa_494_jpg.rf.1e0eb93bf64c7f5296d0c4342682bef2.jpg
#          32.57K 100%   35.03kB/s    0:00:00 (xfr#1593, ir-chk=2042/3643)
# Strawberry/train/images/fresa_494_jpg.rf.765ebbcfbc089b1ab9c1b30c9a22be7b.jpg
#          31.90K 100%   34.27kB/s    0:00:00 (xfr#1594, ir-chk=2041/3643)
# Strawberry/train/images/fresa_494_jpg.rf.87c8b9ee079f68d23c4a0cf3ff9baba1.jpg
#          33.58K 100%   35.14kB/s    0:00:00 (xfr#1595, ir-chk=2040/3643)
# Strawberry/train/images/fresa_496_jpg.rf.73605f04be6cdaffc132b4b39abde92a.jpg
#          44.02K 100%   35.06kB/s    0:00:01 (xfr#1596, ir-chk=2039/3643)
# Strawberry/train/images/fresa_496_jpg.rf.f7bc31ccab80e06bf0bbdbfe362e6ee2.jpg
#          41.52K 100%   39.60MB/s    0:00:00 (xfr#1597, ir-chk=2038/3643)
# Strawberry/train/images/fresa_496_jpg.rf.fc22f136398118593559a78e44c580f1.jpg
#          41.59K 100%  588.63kB/s    0:00:00 (xfr#1598, ir-chk=2037/3643)
# Strawberry/train/images/fresa_497_jpg.rf.09a2405767a1b2e70770280560a8eb1e.jpg
#          37.31K 100%  379.58kB/s    0:00:00 (xfr#1599, ir-chk=2036/3643)
# Strawberry/train/images/fresa_497_jpg.rf.5e9db6a5f4f4c8e630cdb462c2ff3b6d.jpg
#          38.55K 100%  236.75kB/s    0:00:00 (xfr#1600, ir-chk=2035/3643)
# Strawberry/train/images/fresa_497_jpg.rf.b54090d4b184eeb9bec52e011f968c15.jpg
#          40.21K 100%  176.86kB/s    0:00:00 (xfr#1601, ir-chk=2034/3643)
# Strawberry/train/images/fresa_498_jpg.rf.0179f1ee74d56fdb251caf8fc9fc54cd.jpg
#          49.36K 100%  181.91kB/s    0:00:00 (xfr#1602, ir-chk=2033/3643)
# Strawberry/train/images/fresa_498_jpg.rf.44c8602433e8af9de6b97e3991c75465.jpg
#          43.37K 100%  142.59kB/s    0:00:00 (xfr#1603, ir-chk=2032/3643)
# Strawberry/train/images/fresa_498_jpg.rf.849d9bcd277d7d15fefd50a2f235d566.jpg
#          43.18K 100%  124.38kB/s    0:00:00 (xfr#1604, ir-chk=2031/3643)
# Strawberry/train/images/fresa_500_jpg.rf.2c9a1377987eb0a22ce0eac838594433.jpg
#          34.60K 100%   92.58kB/s    0:00:00 (xfr#1605, ir-chk=2030/3643)
# Strawberry/train/images/fresa_500_jpg.rf.5e5c6c5f10e709f947d7c14f8d030fa7.jpg
#          30.61K 100%   81.91kB/s    0:00:00 (xfr#1606, ir-chk=2029/3643)
# Strawberry/train/images/fresa_500_jpg.rf.dc589c04ea7de15ca82bc8e3b761b979.jpg
#          31.41K 100%   75.93kB/s    0:00:00 (xfr#1607, ir-chk=2028/3643)
# Strawberry/train/images/fresa_502_jpg.rf.23578bffbf9079946ae9af4d543f7935.jpg
#          27.55K 100%   66.60kB/s    0:00:00 (xfr#1608, ir-chk=2027/3643)
# Strawberry/train/images/fresa_502_jpg.rf.b30ebfc6f96aae3488d31459baaf5d42.jpg
#          28.50K 100%   44.68kB/s    0:00:00 (xfr#1609, ir-chk=2026/3643)
# Strawberry/train/images/fresa_502_jpg.rf.e0411004006dbee3f5ea2792fe3d2918.jpg
#          28.98K 100%   45.42kB/s    0:00:00 (xfr#1610, ir-chk=2025/3643)
# Strawberry/train/images/fresa_503_jpg.rf.1b22e0ae045bca77f4f0f77037f3292a.jpg
#          34.88K 100%   44.70kB/s    0:00:00 (xfr#1611, ir-chk=2024/3643)
# Strawberry/train/images/fresa_503_jpg.rf.9d7e0b1e05ad0fb564063d72a99d60fb.jpg
#          33.37K 100%   36.62kB/s    0:00:00 (xfr#1612, ir-chk=2023/3643)
# Strawberry/train/images/fresa_503_jpg.rf.b9156d1546df4e67a85ffe6a5aaee337.jpg
#          32.44K 100%   35.59kB/s    0:00:00 (xfr#1613, ir-chk=2022/3643)
# Strawberry/train/images/fresa_506_jpg.rf.20bb277fb3980a6d29b28b379826f47d.jpg
#          36.48K 100%   34.96kB/s    0:00:01 (xfr#1614, ir-chk=2021/3643)
# Strawberry/train/images/fresa_506_jpg.rf.959734c097680849d33409eb4ae58052.jpg
#          36.44K 100%   34.75MB/s    0:00:00 (xfr#1615, ir-chk=2020/3643)
# Strawberry/train/images/fresa_506_jpg.rf.cf61ee685e7aa83e44e067d7b6ea466a.jpg
#          39.92K 100%  207.35kB/s    0:00:00 (xfr#1616, ir-chk=2019/3643)
# Strawberry/train/images/fresa_507_jpg.rf.092dd3c7b8383c47c4166ce6b8acf8bc.jpg
#          44.77K 100%  232.58kB/s    0:00:00 (xfr#1617, ir-chk=2018/3643)
# Strawberry/train/images/fresa_507_jpg.rf.1fb9c5717d8e058a9bdc00b97ac22ff2.jpg
#          50.81K 100%  228.66kB/s    0:00:00 (xfr#1618, ir-chk=2017/3643)
# Strawberry/train/images/fresa_507_jpg.rf.e475a852a145fccf5120ced4ad860150.jpg
#          51.81K 100%  207.35kB/s    0:00:00 (xfr#1619, ir-chk=2016/3643)
# Strawberry/train/images/fresa_509_jpg.rf.3ef51a3bee5dfff53be7baa38fedb6da.jpg
#          36.80K 100%  119.41kB/s    0:00:00 (xfr#1620, ir-chk=2015/3643)
# Strawberry/train/images/fresa_509_jpg.rf.467dc43c82a91cb22bcb6f06d6758c95.jpg
#          40.00K 100%  102.26kB/s    0:00:00 (xfr#1621, ir-chk=2014/3643)
# Strawberry/train/images/fresa_509_jpg.rf.fb9246c1cac462bbbd5c7a3d80a38fb1.jpg
#          40.42K 100%  103.34kB/s    0:00:00 (xfr#1622, ir-chk=2013/3643)
# Strawberry/train/images/fresa_511_jpg.rf.49f34b67703d5353dd159a8b31263a66.jpg
#          48.33K 100%   98.74kB/s    0:00:00 (xfr#1623, ir-chk=2012/3643)
# Strawberry/train/images/fresa_511_jpg.rf.b05bf604eea5a34022afc1d20efa48e2.jpg
#          44.12K 100%   72.78kB/s    0:00:00 (xfr#1624, ir-chk=2011/3643)
# Strawberry/train/images/fresa_511_jpg.rf.b5187ec1ee5380385587335b9d7637dc.jpg
#          50.79K 100%   74.02kB/s    0:00:00 (xfr#1625, ir-chk=2010/3643)
# Strawberry/train/images/fresa_512_jpg.rf.3cdaefc98404243275ebd65fba511601.jpg
#          39.82K 100%   53.41kB/s    0:00:00 (xfr#1626, ir-chk=2009/3643)
# Strawberry/train/images/fresa_512_jpg.rf.aaf64a6956cbfd7eee73ac0bf3d15445.jpg
#          41.04K 100%   42.95kB/s    0:00:00 (xfr#1627, ir-chk=2008/3643)
# Strawberry/train/images/fresa_512_jpg.rf.b8097a6f1586a738d6ab1a09a1c8c9c7.jpg
#          43.08K 100%   45.05kB/s    0:00:00 (xfr#1628, ir-chk=2007/3643)
# Strawberry/train/images/fresa_514_jpg.rf.091218de9e7d6d97060f1a9a404d7e75.jpg
#          45.75K 100%   43.29kB/s    0:00:01 (xfr#1629, ir-chk=2006/3643)
# Strawberry/train/images/fresa_514_jpg.rf.772c35b1ee9c6011c017b9b0c71bf892.jpg
#          48.95K 100%  682.94kB/s    0:00:00 (xfr#1630, ir-chk=2005/3643)
# Strawberry/train/images/fresa_514_jpg.rf.f3d30b243bebce241c5e818f92301931.jpg
#          45.07K 100%  200.06kB/s    0:00:00 (xfr#1631, ir-chk=2004/3643)
# Strawberry/train/images/fresa_515_jpg.rf.4190537044091c874e2f9806d110c372.jpg
#          40.32K 100%  105.85kB/s    0:00:00 (xfr#1632, ir-chk=2003/3643)
# Strawberry/train/images/fresa_515_jpg.rf.4edd6cc4eb15afbe87ac8b0bcad707c6.jpg
#          42.34K 100%   77.58kB/s    0:00:00 (xfr#1633, ir-chk=2002/3643)
# Strawberry/train/images/fresa_515_jpg.rf.df03088b21532e40efffa1c6179fb5bc.jpg
#          42.34K 100%   65.95kB/s    0:00:00 (xfr#1634, ir-chk=2001/3643)
# Strawberry/train/images/fresa_518_jpg.rf.828dd2e90b2a15afd30ab7a7855e712c.jpg
#          39.17K 100%   55.52kB/s    0:00:00 (xfr#1635, ir-chk=2000/3643)
# Strawberry/train/images/fresa_518_jpg.rf.ade410c6c958f6f3e58af52fc2c67446.jpg
#          36.61K 100%   47.86kB/s    0:00:00 (xfr#1636, ir-chk=1999/3643)
# Strawberry/train/images/fresa_518_jpg.rf.cf0458fe8069b135a3891493a5c8048a.jpg
#          38.27K 100%   47.98kB/s    0:00:00 (xfr#1637, ir-chk=1998/3643)
# Strawberry/train/images/fresa_520_jpg.rf.3f032a5b2dfc8ac45683ef503c350c58.jpg
#          33.96K 100%   39.53kB/s    0:00:00 (xfr#1638, ir-chk=1997/3643)
# Strawberry/train/images/fresa_520_jpg.rf.9d9363dcc38b96249f162d99daf262cc.jpg
#          31.79K 100%   34.84kB/s    0:00:00 (xfr#1639, ir-chk=1996/3643)
# Strawberry/train/images/fresa_520_jpg.rf.a86ff19a03aa415a9d8eac6e82d37b08.jpg
#          29.11K 100%   31.90kB/s    0:00:00 (xfr#1640, ir-chk=1995/3643)
# Strawberry/train/images/strawberry001_jpg.rf.2606e2d486ea1b8af4ef47ec5303c0c2.jpg
#          71.03K 100%   55.32kB/s    0:00:01 (xfr#1641, ir-chk=1994/3643)
# Strawberry/train/images/strawberry001_jpg.rf.5b87e561b1c1d9ced972a654dfb21dce.jpg
#          67.02K 100%    1.07MB/s    0:00:00 (xfr#1642, ir-chk=1993/3643)
# Strawberry/train/images/strawberry001_jpg.rf.f1c114b9e7778d1bb134bcd9df76f831.jpg
#          66.55K 100%  618.95kB/s    0:00:00 (xfr#1643, ir-chk=1992/3643)
# Strawberry/train/images/strawberry002_jpg.rf.0f94e943cd3b04f3e22d8445fc3b6c9a.jpg
#          68.53K 100%  241.61kB/s    0:00:00 (xfr#1644, ir-chk=1991/3643)
# Strawberry/train/images/strawberry002_jpg.rf.b8d6c66fb509d5c5473d6cbb7303abd1.jpg
#          70.12K 100%  158.14kB/s    0:00:00 (xfr#1645, ir-chk=1990/3643)
# Strawberry/train/images/strawberry002_jpg.rf.ebf556a36dbd5fdc62d2faf9c9fc4bf2.jpg
#          72.58K 100%  137.09kB/s    0:00:00 (xfr#1646, ir-chk=1989/3643)
# Strawberry/train/images/strawberry003_jpg.rf.2ea32dde7eebc2ed63bca91f05734372.jpg
#          71.31K 100%  103.63kB/s    0:00:00 (xfr#1647, ir-chk=1988/3643)
# Strawberry/train/images/strawberry003_jpg.rf.5f3be05f5c010e985c3a38d47d063f70.jpg
#          63.29K 100%   91.97kB/s    0:00:00 (xfr#1648, ir-chk=1987/3643)
# Strawberry/train/images/strawberry003_jpg.rf.9285138852a952f5329830944076fbd5.jpg
#          64.39K 100%   84.97kB/s    0:00:00 (xfr#1649, ir-chk=1986/3643)
# Strawberry/train/images/strawberry004_jpg.rf.24ed306da6bb611d4b50fe7091056e13.jpg
#          72.18K 100%   84.02kB/s    0:00:00 (xfr#1650, ir-chk=1985/3643)
# Strawberry/train/images/strawberry004_jpg.rf.58038b9dbc4e8969b984c4fe02cf12e3.jpg
#          72.01K 100%   78.93kB/s    0:00:00 (xfr#1651, ir-chk=1984/3643)
# Strawberry/train/images/strawberry004_jpg.rf.87d3f9c64bc2287272c20493d0dfc076.jpg
#          76.77K 100%   78.58kB/s    0:00:00 (xfr#1652, ir-chk=1983/3643)
# Strawberry/train/images/strawberry005_jpg.rf.1cbad776c478bbad4aeb872b3a4fe1b4.jpg
#          65.89K 100%   58.44kB/s    0:00:01 (xfr#1653, ir-chk=1982/3643)
# Strawberry/train/images/strawberry005_jpg.rf.6f5480d166eaa195edb1da706d8d532a.jpg
#          73.95K 100%  451.35kB/s    0:00:00 (xfr#1654, ir-chk=1981/3643)
# Strawberry/train/images/strawberry005_jpg.rf.987dbd0e9428f6dbd2c5cd40c5e71072.jpg
#          64.86K 100%  395.88kB/s    0:00:00 (xfr#1655, ir-chk=1980/3643)
# Strawberry/train/images/strawberry006_jpg.rf.29e50aa258585d3875c265aa434a6981.jpg
#          71.90K 100%  178.22kB/s    0:00:00 (xfr#1656, ir-chk=1979/3643)
# Strawberry/train/images/strawberry006_jpg.rf.2b37c0965020665be4e3a5b40101b1c5.jpg
#          72.25K 100%  162.58kB/s    0:00:00 (xfr#1657, ir-chk=1978/3643)
# Strawberry/train/images/strawberry006_jpg.rf.7c8b0012bb44e0393d01a1b2e1f5b728.jpg
#          73.56K 100%  152.52kB/s    0:00:00 (xfr#1658, ir-chk=1977/3643)
# Strawberry/train/images/strawberry007_jpg.rf.166c63a19c78b592f4375eb60ff5a00d.jpg
#          85.83K 100%  164.68kB/s    0:00:00 (xfr#1659, ir-chk=1976/3643)
# Strawberry/train/images/strawberry007_jpg.rf.322f805001506b7f2aea51e4bc0bb371.jpg
#          77.93K 100%  114.10kB/s    0:00:00 (xfr#1660, ir-chk=1975/3643)
# Strawberry/train/images/strawberry007_jpg.rf.5303a63a6b904f9c7ef0df9639b33e6d.jpg
#          76.17K 100%   90.38kB/s    0:00:00 (xfr#1661, ir-chk=1974/3643)
# Strawberry/train/images/strawberry008_jpg.rf.98d002cc74287f3aaf3e5529801b89e3.jpg
# ...
# Strawberry/valid/images/fresa_516_jpg.rf.ecec5a6d2284a4b087dd6f0e61d8ee58.jpg
#          43.71K 100%   64.48kB/s    0:00:00 (xfr#3737, to-chk=106/3853)
# Strawberry/valid/images/fresa_517_jpg.rf.d98421228711afe3f25c77d72aa0259d.jpg
#          34.43K 100%   50.79kB/s    0:00:00 (xfr#3738, to-chk=105/3853)
# Strawberry/valid/images/fresa_519_jpg.rf.34c5dbed63f644a6cd749b4956d20b7c.jpg
#          31.86K 100%   44.77kB/s    0:00:00 (xfr#3739, to-chk=104/3853)
# Strawberry/valid/labels/
# Strawberry/valid/labels/fresa_006_jpg.rf.e059841d84b592b40d664780ab78bced.txt
#           2.18K 100%    3.06kB/s    0:00:00 (xfr#3740, to-chk=103/3853)
# Strawberry/valid/labels/fresa_012_jpg.rf.b9050d6afce36c5dd8286a8e55024e42.txt
#           3.91K 100%    5.49kB/s    0:00:00 (xfr#3741, to-chk=102/3853)
# Strawberry/valid/labels/fresa_019_jpg.rf.f8095871a9cc4e543f97e45d7867d1c7.txt
#               0 100%    0.00kB/s    0:00:00 (xfr#3742, to-chk=101/3853)
# Strawberry/valid/labels/fresa_022_jpg.rf.6c5ab299538769d0a57974a20de67b2f.txt
#           2.74K 100%    3.85kB/s    0:00:00 (xfr#3743, to-chk=100/3853)
# Strawberry/valid/labels/fresa_026_jpg.rf.7fbaed017c1775550fc189d3a1f331d6.txt
#           5.71K 100%    8.02kB/s    0:00:00 (xfr#3744, to-chk=99/3853)
# Strawberry/valid/labels/fresa_033_jpg.rf.8f496399b6cf4b55ff98990e2f41ca95.txt
#           6.01K 100%    8.45kB/s    0:00:00 (xfr#3745, to-chk=98/3853)
# Strawberry/valid/labels/fresa_037_jpg.rf.493eb7cf1d08a118e4592ade44d9c452.txt
#           3.38K 100%    4.75kB/s    0:00:00 (xfr#3746, to-chk=97/3853)
# Strawberry/valid/labels/fresa_039_jpg.rf.2a30f93df6e449e8c20b8a68a270644c.txt
#          11.99K 100%   16.85kB/s    0:00:00 (xfr#3747, to-chk=96/3853)
# Strawberry/valid/labels/fresa_051_jpg.rf.85702573be4603e115fb22e816aa09ab.txt
#           5.46K 100%    7.66kB/s    0:00:00 (xfr#3748, to-chk=95/3853)
# Strawberry/valid/labels/fresa_054_jpg.rf.665c844cb3539983bf8227a2a0d2dfb6.txt
#           3.17K 100%    4.45kB/s    0:00:00 (xfr#3749, to-chk=94/3853)
# Strawberry/valid/labels/fresa_055_jpg.rf.d1c3accfca5670812145b37c11d3e0bf.txt
#           7.52K 100%   10.56kB/s    0:00:00 (xfr#3750, to-chk=93/3853)
# Strawberry/valid/labels/fresa_056_jpg.rf.7e2a5468d93f7dde3d9ac1f134393e7c.txt
#           4.99K 100%    7.01kB/s    0:00:00 (xfr#3751, to-chk=92/3853)
# Strawberry/valid/labels/fresa_058_jpg.rf.e49c72bd5f641b69a99e2fa8a02ba2ce.txt
#               0 100%    0.00kB/s    0:00:00 (xfr#3752, to-chk=91/3853)
# Strawberry/valid/labels/fresa_076_jpg.rf.c56341b854f86ec54c8cda17edc149d0.txt
#           4.05K 100%    5.69kB/s    0:00:00 (xfr#3753, to-chk=90/3853)
# Strawberry/valid/labels/fresa_082_jpg.rf.c29170692bc847b563b5ea085e9e16d6.txt
#           9.72K 100%   13.66kB/s    0:00:00 (xfr#3754, to-chk=89/3853)
# Strawberry/valid/labels/fresa_086_jpg.rf.523c70f6d2515904a400af9c16e89cd9.txt
#           5.92K 100%    8.32kB/s    0:00:00 (xfr#3755, to-chk=88/3853)
# Strawberry/valid/labels/fresa_090_jpg.rf.b40a59caaf5bf9b3e2910640e6235a9c.txt
#           1.10K 100%    1.55kB/s    0:00:00 (xfr#3756, to-chk=87/3853)
# Strawberry/valid/labels/fresa_091_jpg.rf.a16a2919e3ca62679ed602487991d18f.txt
#           8.64K 100%   12.14kB/s    0:00:00 (xfr#3757, to-chk=86/3853)
# Strawberry/valid/labels/fresa_096_jpg.rf.d90b9e4e9a5e0e340ee51217999e6dc4.txt
#           3.62K 100%    4.88kB/s    0:00:00 (xfr#3758, to-chk=85/3853)
# Strawberry/valid/labels/fresa_104_jpg.rf.cce3ee057a64f2fdebe95ef9ee1fbe5b.txt
#           2.88K 100%    3.88kB/s    0:00:00 (xfr#3759, to-chk=84/3853)
# Strawberry/valid/labels/fresa_106_jpg.rf.024962a6b552d231abea4b41ec0fb61e.txt
#           2.77K 100%    3.74kB/s    0:00:00 (xfr#3760, to-chk=83/3853)
# Strawberry/valid/labels/fresa_117_jpg.rf.9eede09265255b4434fc7c265c51012c.txt
#               0 100%    0.00kB/s    0:00:00 (xfr#3761, to-chk=82/3853)
# Strawberry/valid/labels/fresa_122_jpg.rf.7054473a05591f79d621e826bac50c44.txt
#           6.43K 100%    8.68kB/s    0:00:00 (xfr#3762, to-chk=81/3853)
# Strawberry/valid/labels/fresa_123_jpg.rf.2ef0f76b42daee698d9f05c6a9bfbc23.txt
#           3.14K 100%    4.24kB/s    0:00:00 (xfr#3763, to-chk=80/3853)
# Strawberry/valid/labels/fresa_135_jpg.rf.9dda1992291efeb896c6946b6ef71780.txt
#           2.10K 100%    2.84kB/s    0:00:00 (xfr#3764, to-chk=79/3853)
# Strawberry/valid/labels/fresa_141_jpg.rf.b7d63bdf5359d0ede30410d06ca72c9f.txt
#           1.97K 100%    2.66kB/s    0:00:00 (xfr#3765, to-chk=78/3853)
# Strawberry/valid/labels/fresa_157_jpg.rf.ee1f6c4d6380a615cee9927e654af694.txt
#           2.14K 100%    2.89kB/s    0:00:00 (xfr#3766, to-chk=77/3853)
# Strawberry/valid/labels/fresa_162_jpg.rf.f1f4c1ed093a17e951e81192bd322ec7.txt
#           2.73K 100%    3.68kB/s    0:00:00 (xfr#3767, to-chk=76/3853)
# Strawberry/valid/labels/fresa_172_jpg.rf.78af99549d94cf21aa7834f1518d4f8c.txt
#           2.11K 100%    2.84kB/s    0:00:00 (xfr#3768, to-chk=75/3853)
# Strawberry/valid/labels/fresa_177_jpg.rf.bfc14cf8254cdc53b7af755cefcb97b6.txt
#           4.47K 100%    6.03kB/s    0:00:00 (xfr#3769, to-chk=74/3853)
# Strawberry/valid/labels/fresa_179_jpg.rf.fb3dec7dffcfad7dbcc434a54e731779.txt
#           2.52K 100%    3.40kB/s    0:00:00 (xfr#3770, to-chk=73/3853)
# Strawberry/valid/labels/fresa_193_jpg.rf.7ddca74ff59b67fc7484b8b9d1b828ef.txt
#           1.96K 100%    2.64kB/s    0:00:00 (xfr#3771, to-chk=72/3853)
# Strawberry/valid/labels/fresa_195_jpg.rf.400fa4489f20cccae285435dd0670e3a.txt
#           1.12K 100%    1.51kB/s    0:00:00 (xfr#3772, to-chk=71/3853)
# Strawberry/valid/labels/fresa_198_jpg.rf.c9491510ae50930aed275723a0cf1d5c.txt
#           1.47K 100%    1.99kB/s    0:00:00 (xfr#3773, to-chk=70/3853)
# Strawberry/valid/labels/fresa_199_jpg.rf.bf26b89ebfc9e69fb0a85aa042a63fc1.txt
#           1.41K 100%    1.91kB/s    0:00:00 (xfr#3774, to-chk=69/3853)
# Strawberry/valid/labels/fresa_206_jpg.rf.3f4da9d7912e1a17a081a45a932cafba.txt
#           1.23K 100%    1.66kB/s    0:00:00 (xfr#3775, to-chk=68/3853)
# Strawberry/valid/labels/fresa_211_jpg.rf.74e39d5a3f40afb0805f42ab295371b2.txt
#           1.74K 100%    2.35kB/s    0:00:00 (xfr#3776, to-chk=67/3853)
# Strawberry/valid/labels/fresa_213_jpg.rf.9dab2a618c807d7168e84e16dba37384.txt
#               0 100%    0.00kB/s    0:00:00 (xfr#3777, to-chk=66/3853)
# Strawberry/valid/labels/fresa_214_jpg.rf.494adef38dcb38c1e336211e928d7cf8.txt
#           3.79K 100%    5.11kB/s    0:00:00 (xfr#3778, to-chk=65/3853)
# Strawberry/valid/labels/fresa_227_jpg.rf.b7687c17e2e5c1f3b412f92d760b7086.txt
#           2.43K 100%    3.28kB/s    0:00:00 (xfr#3779, to-chk=64/3853)
# Strawberry/valid/labels/fresa_228_jpg.rf.fe3a5491c6797c9c72bae71419a7b8b2.txt
#           2.14K 100%    2.89kB/s    0:00:00 (xfr#3780, to-chk=63/3853)
# Strawberry/valid/labels/fresa_230_jpg.rf.40a18ec4499e309d58eacd8f5b3c52bd.txt
#           2.31K 100%    3.12kB/s    0:00:00 (xfr#3781, to-chk=62/3853)
# Strawberry/valid/labels/fresa_231_jpg.rf.a07a6730a36413d0eec08bbd17342a94.txt
#           4.05K 100%    5.46kB/s    0:00:00 (xfr#3782, to-chk=61/3853)
# Strawberry/valid/labels/fresa_242_jpg.rf.cf9e85d35265caca3d781be71cc9d018.txt
#           1.83K 100%    2.47kB/s    0:00:00 (xfr#3783, to-chk=60/3853)
# Strawberry/valid/labels/fresa_250_jpg.rf.f3911e8dc00b796166fe8f86932355f7.txt
#           3.76K 100%    4.14kB/s    0:00:00 (xfr#3784, to-chk=59/3853)
# Strawberry/valid/labels/fresa_252_jpg.rf.8cfa4d767cd988034b110daa1458d8ea.txt
#           5.89K 100%    6.49kB/s    0:00:00 (xfr#3785, to-chk=58/3853)
# Strawberry/valid/labels/fresa_256_jpg.rf.e49c237a046a531a4da37aac25f09813.txt
#           2.42K 100%    2.67kB/s    0:00:00 (xfr#3786, to-chk=57/3853)
# Strawberry/valid/labels/fresa_260_jpg.rf.7f80309b18c91e7b13fd13d9699b9412.txt
#           4.56K 100%    5.02kB/s    0:00:00 (xfr#3787, to-chk=56/3853)
# Strawberry/valid/labels/fresa_263_jpg.rf.b5490f3f4c667aa60b485aa718051b81.txt
#           2.01K 100%    2.21kB/s    0:00:00 (xfr#3788, to-chk=55/3853)
# Strawberry/valid/labels/fresa_269_jpg.rf.9067bdc23096149c7125597e553cc17a.txt
#           2.37K 100%    2.61kB/s    0:00:00 (xfr#3789, to-chk=54/3853)
# Strawberry/valid/labels/fresa_274_jpg.rf.8f7b349b50be894554152f7d281c5f53.txt
#           3.37K 100%    3.71kB/s    0:00:00 (xfr#3790, to-chk=53/3853)
# Strawberry/valid/labels/fresa_275_jpg.rf.296fea028bebdd565750f956b3c29fe6.txt
#           2.88K 100%    3.17kB/s    0:00:00 (xfr#3791, to-chk=52/3853)
# Strawberry/valid/labels/fresa_281_jpg.rf.e900126e9afa50d0fa5feee58210ae77.txt
#           1.59K 100%    1.75kB/s    0:00:00 (xfr#3792, to-chk=51/3853)
# Strawberry/valid/labels/fresa_284_jpg.rf.61e8a3ed936d58e2113bd316c40e3fc0.txt
#           1.50K 100%    1.65kB/s    0:00:00 (xfr#3793, to-chk=50/3853)
# Strawberry/valid/labels/fresa_294_jpg.rf.45db331f9c0b2477dcfd37bb2f1da699.txt
#           1.12K 100%    1.24kB/s    0:00:00 (xfr#3794, to-chk=49/3853)
# Strawberry/valid/labels/fresa_297_jpg.rf.305fa9d7cba0e2c6cad54145b5cdb1f1.txt
#             758 100%    0.83kB/s    0:00:00 (xfr#3795, to-chk=48/3853)
# Strawberry/valid/labels/fresa_306_jpg.rf.69466fe7b2c85f1f1309f16ce8f5b47b.txt
#           3.28K 100%    3.61kB/s    0:00:00 (xfr#3796, to-chk=47/3853)
# Strawberry/valid/labels/fresa_307_jpg.rf.0071c103a805a4db75328ecb0f60739c.txt
#           3.80K 100%    4.18kB/s    0:00:00 (xfr#3797, to-chk=46/3853)
# Strawberry/valid/labels/fresa_323_jpg.rf.c58fb5417da7be6c696006af7645beb6.txt
#           1.41K 100%    1.55kB/s    0:00:00 (xfr#3798, to-chk=45/3853)
# Strawberry/valid/labels/fresa_333_jpg.rf.e07dc047087872eaa54a8e9637f87e79.txt
#           2.38K 100%    2.62kB/s    0:00:00 (xfr#3799, to-chk=44/3853)
# Strawberry/valid/labels/fresa_343_jpg.rf.920520578af12b876d6dcb9ab2cd8472.txt
#           4.61K 100%    5.07kB/s    0:00:00 (xfr#3800, to-chk=43/3853)
# Strawberry/valid/labels/fresa_344_jpg.rf.cb8577f8c806e3d84e97510bc035057c.txt
#           1.87K 100%    2.06kB/s    0:00:00 (xfr#3801, to-chk=42/3853)
# Strawberry/valid/labels/fresa_345_jpg.rf.df12e8d3894e0881395a0f13ad368b87.txt
#           6.28K 100%    6.92kB/s    0:00:00 (xfr#3802, to-chk=41/3853)
# Strawberry/valid/labels/fresa_347_jpg.rf.0ed5a8fefc0f2953c8ca8eb0f53b970f.txt
#           4.28K 100%    4.71kB/s    0:00:00 (xfr#3803, to-chk=40/3853)
# Strawberry/valid/labels/fresa_351_jpg.rf.84fc97239fb32dca79516a4aba79ac23.txt
#           2.43K 100%    2.68kB/s    0:00:00 (xfr#3804, to-chk=39/3853)
# Strawberry/valid/labels/fresa_354_jpg.rf.c78d74dcfc40f8c65ed0f423ac3393d1.txt
#           2.96K 100%    2.60kB/s    0:00:01 (xfr#3805, to-chk=38/3853)
# Strawberry/valid/labels/fresa_357_jpg.rf.df0448c3378e27c3dbe32a05ab468677.txt
#           3.49K 100%    3.07kB/s    0:00:01 (xfr#3806, to-chk=37/3853)
# Strawberry/valid/labels/fresa_361_jpg.rf.7cadc09a1336b03b5ead3dd30c6bedff.txt
#           2.68K 100%    2.35kB/s    0:00:01 (xfr#3807, to-chk=36/3853)
# Strawberry/valid/labels/fresa_363_jpg.rf.718a444badd06e5e0336b6e2419d9f50.txt
#           2.98K 100%    2.62kB/s    0:00:01 (xfr#3808, to-chk=35/3853)
# Strawberry/valid/labels/fresa_368_jpg.rf.8ffc47a6a3a95ea878abb4a4b90c1fd9.txt
#           1.72K 100%    1.51kB/s    0:00:01 (xfr#3809, to-chk=34/3853)
# Strawberry/valid/labels/fresa_378_jpg.rf.49a817df0e328b5ac1a0ab775b110919.txt
#           2.39K 100%    2.10kB/s    0:00:01 (xfr#3810, to-chk=33/3853)
# Strawberry/valid/labels/fresa_380_jpg.rf.e7283b65b62268ed541d27fbb4d5bc9c.txt
#           2.80K 100%    2.46kB/s    0:00:01 (xfr#3811, to-chk=32/3853)
# Strawberry/valid/labels/fresa_382_jpg.rf.8721d758080b088305fa33883ad2306e.txt
#           3.98K 100%    3.50kB/s    0:00:01 (xfr#3812, to-chk=31/3853)
# Strawberry/valid/labels/fresa_388_jpg.rf.c08d5d01cebf602630dc3978997aac69.txt
#           4.68K 100%    4.11kB/s    0:00:01 (xfr#3813, to-chk=30/3853)
# Strawberry/valid/labels/fresa_396_jpg.rf.01423c7d2873dda8f4a27169a506621d.txt
#           2.85K 100%    2.50kB/s    0:00:01 (xfr#3814, to-chk=29/3853)
# Strawberry/valid/labels/fresa_400_jpg.rf.7176c26235070dacbc6f8e6967f58b2e.txt
#           3.04K 100%    2.67kB/s    0:00:01 (xfr#3815, to-chk=28/3853)
# Strawberry/valid/labels/fresa_401_jpg.rf.45e87f35485980e5ff1518b908b1c32e.txt
#           1.62K 100%    1.42kB/s    0:00:01 (xfr#3816, to-chk=27/3853)
# Strawberry/valid/labels/fresa_404_jpg.rf.a16256d9f9c4c21d8a3046e0d64c7307.txt
#           2.94K 100%    2.59kB/s    0:00:01 (xfr#3817, to-chk=26/3853)
# Strawberry/valid/labels/fresa_406_jpg.rf.ac1c52b50587441381ea2267d337c3cd.txt
#           2.87K 100%    2.52kB/s    0:00:01 (xfr#3818, to-chk=25/3853)
# Strawberry/valid/labels/fresa_413_jpg.rf.ea6fb4d7792e1cb71a268137c04cd264.txt
#           3.37K 100%    2.96kB/s    0:00:01 (xfr#3819, to-chk=24/3853)
# Strawberry/valid/labels/fresa_415_jpg.rf.3b6a0f60be02a4df9d22a482207e87a5.txt
#             123 100%    0.11kB/s    0:00:01 (xfr#3820, to-chk=23/3853)
# Strawberry/valid/labels/fresa_423_jpg.rf.7b33ddfc4aba077bacee023ce0c3a57c.txt
#           3.92K 100%    3.44kB/s    0:00:01 (xfr#3821, to-chk=22/3853)
# Strawberry/valid/labels/fresa_427_jpg.rf.a578b448a3c34aa46d4101e57b627660.txt
#           2.66K 100%    2.34kB/s    0:00:01 (xfr#3822, to-chk=21/3853)
# Strawberry/valid/labels/fresa_430_jpg.rf.46fd5a2a9fa856dd7964217169acf094.txt
#           2.40K 100%    2.11kB/s    0:00:01 (xfr#3823, to-chk=20/3853)
# Strawberry/valid/labels/fresa_433_jpg.rf.99a14d2ed28f9cdf566bf3d98ddad3e5.txt
#           1.38K 100%    1.21kB/s    0:00:01 (xfr#3824, to-chk=19/3853)
# Strawberry/valid/labels/fresa_438_jpg.rf.db8c34e5024e4ff619edadb8f735fb5c.txt
#           2.91K 100%    2.55kB/s    0:00:01 (xfr#3825, to-chk=18/3853)
# Strawberry/valid/labels/fresa_441_jpg.rf.26a11c22de1909006849d9e8bc9d4054.txt
#           1.80K 100%    1.58kB/s    0:00:01 (xfr#3826, to-chk=17/3853)
# Strawberry/valid/labels/fresa_447_jpg.rf.a5dcd75f33340c6229eec02bfe176e8d.txt
#           1.68K 100%    1.47kB/s    0:00:01 (xfr#3827, to-chk=16/3853)
# Strawberry/valid/labels/fresa_456_jpg.rf.f9c0eddc2e8d876e40dbf55a4903e5ad.txt
#           2.77K 100%    2.43kB/s    0:00:01 (xfr#3828, to-chk=15/3853)
# Strawberry/valid/labels/fresa_465_jpg.rf.8e4632015c6c103ee1026016f412c554.txt
#           1.58K 100%    0.00kB/s    0:00:00 (xfr#3829, to-chk=14/3853)
# Strawberry/valid/labels/fresa_473_jpg.rf.1184bc10fcdba0378c00a8073331f4e8.txt
#           1.11K 100%    1.06MB/s    0:00:00 (xfr#3830, to-chk=13/3853)
# Strawberry/valid/labels/fresa_475_jpg.rf.f133be0ef5872c14e5bc760ba254dfe8.txt
#           2.20K 100%    2.10MB/s    0:00:00 (xfr#3831, to-chk=12/3853)
# Strawberry/valid/labels/fresa_485_jpg.rf.072d4621084591bd8ee5845ad3c554a8.txt
#           3.86K 100%    3.68MB/s    0:00:00 (xfr#3832, to-chk=11/3853)
# Strawberry/valid/labels/fresa_488_jpg.rf.96a30daffb7d7d1d508c73a9429dbe88.txt
#           2.31K 100%    2.21MB/s    0:00:00 (xfr#3833, to-chk=10/3853)
# Strawberry/valid/labels/fresa_490_jpg.rf.1bfa84d9f3551949752c75456d0af387.txt
#           2.17K 100%    2.07MB/s    0:00:00 (xfr#3834, to-chk=9/3853)
# Strawberry/valid/labels/fresa_491_jpg.rf.551237f8ce18ef4cfb4eff6d5644b314.txt
#           1.14K 100%  557.62kB/s    0:00:00 (xfr#3835, to-chk=8/3853)
# Strawberry/valid/labels/fresa_495_jpg.rf.814c1bd1e357adeffd3dc8dd66671203.txt
#           2.18K 100%    1.04MB/s    0:00:00 (xfr#3836, to-chk=7/3853)
# Strawberry/valid/labels/fresa_499_jpg.rf.5b534f76fc0a84bc06f7dcb9fb047bf8.txt
#           3.20K 100%    1.53MB/s    0:00:00 (xfr#3837, to-chk=6/3853)
# Strawberry/valid/labels/fresa_504_jpg.rf.4bb13df1dada552ec7a5c2f2ce7a14ba.txt
#           3.52K 100%    1.68MB/s    0:00:00 (xfr#3838, to-chk=5/3853)
# Strawberry/valid/labels/fresa_505_jpg.rf.2dac336d482b6af1013784bd4d362b80.txt
#           3.38K 100%    1.61MB/s    0:00:00 (xfr#3839, to-chk=4/3853)
# Strawberry/valid/labels/fresa_510_jpg.rf.17318e8061d7ea8fd4b587ffb9e247b5.txt
#           1.77K 100%  575.52kB/s    0:00:00 (xfr#3840, to-chk=3/3853)
# Strawberry/valid/labels/fresa_516_jpg.rf.ecec5a6d2284a4b087dd6f0e61d8ee58.txt
#           2.80K 100%  910.81kB/s    0:00:00 (xfr#3841, to-chk=2/3853)
# Strawberry/valid/labels/fresa_517_jpg.rf.d98421228711afe3f25c77d72aa0259d.txt
#           2.13K 100%  693.03kB/s    0:00:00 (xfr#3842, to-chk=1/3853)
# Strawberry/valid/labels/fresa_519_jpg.rf.34c5dbed63f644a6cd749b4956d20b7c.txt
#           2.43K 100%  791.99kB/s    0:00:00 (xfr#3843, to-chk=0/3853)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="SYEm6T8HXuCwRk6VO9Up")
project = rf.workspace("sannanabbasi").project("strawberry-gzxcf-pgnod")
version = project.version(3)
dataset = version.download("yolov11")
# Out:
# Collecting roboflow
#   Downloading roboflow-1.2.9-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from roboflow) (2025.8.3)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.0.2)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (11.3.0)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.5 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.2-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.32.4)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (4.60.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (3.2.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->roboflow) (3.4.3)
# Downloading roboflow-1.2.9-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.7/88.7 kB 5.8 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.9 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 24.1 MB/s eta 0:00:00
# Downloading pi_heif-1.1.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 62.5 MB/s eta 0:00:00
# Downloading pillow_avif_plugin-1.5.2-cp312-cp312-manylinux_2_28_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 132.1 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Installing collected packages: pillow-avif-plugin, filetype, pi-heif, opencv-python-headless, idna, roboflow
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pi-heif-1.1.1 pillow-avif-plugin-1.5.2 roboflow-1.2.9
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in strawberry-3 to yolov11:: 100%|██████████| 92828/92828 [00:01<00:00, 55799.04it/s]
# Extracting Dataset Version Zip to strawberry-3 in yolov11:: 100%|██████████| 3852/3852 [00:00<00:00, 6580.92it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="SYEm6T8HXuCwRk6VO9Up")
project = rf.workspace("sannanabbasi").project("avocado-segmentation-wqss9")
version = project.version(3)
dataset = version.download("yolov11")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.12/dist-packages (1.2.9)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from roboflow) (2025.8.3)
# Requirement already satisfied: idna==3.7 in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.0.2)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (11.3.0)
# Requirement already satisfied: pi-heif<2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.1.1)
# Requirement already satisfied: pillow-avif-plugin<2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.5.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.32.4)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (4.60.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (3.2.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->roboflow) (3.4.3)
# loading Roboflow workspace...
# loading Roboflow project...
# Exporting format yolov11 in progress : 85.0%
# Version export complete for yolov11 format
# Downloading Dataset Version Zip in Avocado-Segmentation-3 to yolov11:: 100%|██████████| 75507/75507 [00:01<00:00, 63515.69it/s]
# Extracting Dataset Version Zip to Avocado-Segmentation-3 in yolov11:: 100%|██████████| 3172/3172 [00:00<00:00, 6753.02it/s]

# %%
# 2) CONFIG — point to your Roboflow YAML
from pathlib import Path
YAML_PATH = Path("/content/strawberry-3/data.yaml")  # <-- CHANGE THIS

# Optional: if you want to remove images that end up with no labels
DELETE_EMPTY_LABEL_IMAGES = False

# 3) Filter out 'strawberry-stem' and keep only 'strawberry' (class 0)
import yaml, os, shutil

with open(YAML_PATH, "r") as f:
    y = yaml.safe_load(f)

names = [str(n) for n in y.get("names", [])]
if not names:
    raise RuntimeError("No 'names' found in YAML.")

# Find indices
if "strawberry" not in names:
    raise RuntimeError("'strawberry' not found in names list.")
straw_idx = names.index("strawberry")

stem_idx = None
if "strawberry-stem" in names:
    stem_idx = names.index("strawberry-stem")
else:
    print("Note: 'strawberry-stem' not in names; nothing to remove.")

# Resolve split image/label dirs from YAML (train/val/test keys may vary)
def resolve_img_dir(key):
    if key not in y:
        return None
    p = Path(y[key])
    # make absolute relative to YAML location if needed
    return (YAML_PATH.parent / p).resolve() if not p.is_absolute() else p

splits = {}
for k in ["train", "val", "valid", "test"]:
    img_dir = resolve_img_dir(k)
    if img_dir and img_dir.exists():
        # YOLO convention: labels folder mirrors images
        lbl_dir = Path(str(img_dir).replace(os.sep + "images", os.sep + "labels"))
        if not lbl_dir.exists():
            print(f"Warning: labels dir not found for {k}: {lbl_dir}")
        splits[k] = (img_dir, lbl_dir)

total_files = 0
removed_lines = 0
kept_lines = 0
emptied = 0

def filter_label_file(lbl_path):
    global removed_lines, kept_lines, emptied
    if not lbl_path.exists():
        return False, 0  # (emptied?, remaining_count)
    lines = [L.strip() for L in lbl_path.read_text(encoding="utf-8").splitlines() if L.strip()]
    out = []
    for L in lines:
        parts = L.split()
        try:
            cls = int(float(parts[0]))
        except:
            continue
        # Drop stems
        if stem_idx is not None and cls == stem_idx:
            removed_lines += 1
            continue
        # Keep strawberries, remap to 0
        if cls == straw_idx:
            parts[0] = "0"
            out.append(" ".join(parts))
            kept_lines += 1
        else:
            # Any unexpected class -> drop
            removed_lines += 1

    # Write back (empty file allowed = negative image)
    lbl_path.write_text("\n".join(out), encoding="utf-8")
    if len(out) == 0:
        emptied += 1
        return True, 0
    return False, len(out)

for split, (img_dir, lbl_dir) in splits.items():
    if not lbl_dir.exists():
        continue
    print(f"Processing split: {split}")
    # iterate images to decide optional deletions when labels become empty
    img_files = []
    for ext in ("*.jpg","*.jpeg","*.png","*.bmp","*.webp"):
        img_files += list(img_dir.rglob(ext))
    for img_p in img_files:
        total_files += 1
        stem = img_p.stem
        lbl_p = lbl_dir / f"{stem}.txt"
        emptied_flag, rem_count = filter_label_file(lbl_p)

        if DELETE_EMPTY_LABEL_IMAGES and emptied_flag:
            # remove both image and label if labels now empty
            try:
                img_p.unlink(missing_ok=True)
                lbl_p.unlink(missing_ok=True)
            except Exception as e:
                print("Delete error:", e)

# 4) Update YAML to single-class strawberry
y["names"] = ["strawberry"]
y["nc"] = 1
with open(YAML_PATH, "w") as f:
    yaml.safe_dump(y, f, sort_keys=False)

print("Done.\n"
      f"Images seen: {total_files}\n"
      f"Label lines kept (strawberry): {kept_lines}\n"
      f"Label lines removed (stem/others): {removed_lines}\n"
      f"Empty label files after filter: {emptied}\n"
      f"YAML updated to nc=1, names=['strawberry'] at: {YAML_PATH}")
# Out:
# Done.
# Images seen: 0
# Label lines kept (strawberry): 0
# Label lines removed (stem/others): 0
# Empty label files after filter: 0
# YAML updated to nc=1, names=['strawberry'] at: /content/strawberry-3/data.yaml

# %%
# === CONFIG: point to your YAML ===
from pathlib import Path
YAML_PATH = Path("/content/strawberry-3/data.yaml")  # <-- change if different
DELETE_EMPTY_LABEL_IMAGES = False

import yaml, os, re
from glob import glob

ROOT = YAML_PATH.parent.resolve()

# Load YAML (still update to single-class later)
with open(YAML_PATH, "r") as f:
    y = yaml.safe_load(f)

# --- 1) Find real split folders robustly ---
def find_split_images_dir(split_name: str):
    """
    Returns a Path to the images dir for the split, or None.
    Priority:
      a) use YAML value if exists,
      b) ROOT/split/images,
      c) any .../split/images found under ROOT (recursive)
    """
    cand = None
    if split_name in y:
        p = Path(y[split_name])
        cand = (ROOT / p).resolve() if not p.is_absolute() else p
        if cand.exists():
            return cand

    # ROOT/split/images
    p2 = ROOT / split_name / "images"
    if p2.exists():
        return p2

    # recursive search
    hits = [Path(d) for d in glob(str(ROOT / "**/images"), recursive=True)
            if Path(d).parent.name.lower() == split_name]
    return hits[0] if hits else None

splits_order = ["train", "valid", "val", "test"]
img_dirs = {s: find_split_images_dir(s) for s in splits_order}
img_dirs = {k:v for k,v in img_dirs.items() if v is not None}

if not img_dirs:
    raise RuntimeError("Could not locate any split images directories under "
                       f"{ROOT}. Please check the dataset structure.")

print("Discovered images dirs:")
for k,v in img_dirs.items():
    print(f"  {k}: {v}")

# Derive label dirs as sibling: .../<split>/labels
label_dirs = {}
for split, img_dir in img_dirs.items():
    split_root = img_dir.parent           # .../<split>
    lbl_dir = split_root / "labels"       # .../<split>/labels
    if lbl_dir.exists():
        label_dirs[split] = lbl_dir

if not label_dirs:
    raise RuntimeError("No labels directories found next to images. "
                       "Expected .../<split>/labels for each split.")

print("Discovered label dirs:")
for k,v in label_dirs.items():
    print(f"  {k}: {v}")

# --- 2) Scrub labels: keep only class 0; drop all others ---
# This works even if names included 'strawberry-stem' previously,
# because we force everything except class 0 to be removed.

def rewrite_label(lbl_path: Path):
    if not lbl_path.exists():
        return (0,0,False)
    lines = [L.strip() for L in lbl_path.read_text(encoding="utf-8").splitlines() if L.strip()]
    out = []
    kept = removed = 0
    for L in lines:
        parts = L.split()
        # first token is class id (int)
        try:
            cls = int(float(parts[0]))
        except:
            removed += 1
            continue
        if cls == 0:
            # keep strawberry as class 0
            out.append(" ".join(["0"] + parts[1:]))
            kept += 1
        else:
            # drop any other class (e.g., 1 = strawberry-stem)
            removed += 1
    lbl_path.write_text("\n".join(out), encoding="utf-8")
    return (kept, removed, len(out) == 0)

kept_total = removed_total = emptied_total = files_total = 0
for split, lbl_dir in label_dirs.items():
    for lbl_path in lbl_dir.rglob("*.txt"):
        files_total += 1
        k, r, emptied = rewrite_label(lbl_path)
        kept_total += k
        removed_total += r
        if emptied and DELETE_EMPTY_LABEL_IMAGES:
            stem = lbl_path.stem
            img_dir = img_dirs[split]
            for ext in (".jpg",".jpeg",".png",".bmp",".webp"):
                img_path = img_dir / f"{stem}{ext}"
                if img_path.exists():
                    try: img_path.unlink()
                    except: pass
            try: lbl_path.unlink()
            except: pass
            emptied_total += 1

print(f"\nProcessed label files: {files_total}")
print(f"Kept class-0 (strawberry) lines: {kept_total}")
print(f"Removed non-zero class lines: {removed_total}")
print(f"Deleted empty-label images: {emptied_total} (DELETE_EMPTY_LABEL_IMAGES={DELETE_EMPTY_LABEL_IMAGES})")

# --- 3) Normalize YAML: single-class + portable split paths ---
# Prefer 'train' and 'val' keys. If only 'valid' exists, create 'val'.
new_yaml = dict(y)  # copy
new_yaml["names"] = ["strawberry"]
new_yaml["nc"] = 1

def rel_from_root(p: Path):
    return str(p.relative_to(ROOT)).replace("\\", "/")

if "train" in img_dirs:
    new_yaml["train"] = rel_from_root(img_dirs["train"])
if "val" in img_dirs:
    new_yaml["val"] = rel_from_root(img_dirs["val"])
elif "valid" in img_dirs:
    new_yaml["val"] = rel_from_root(img_dirs["valid"])
if "test" in img_dirs:
    new_yaml["test"] = rel_from_root(img_dirs["test"])

# Write back
with open(YAML_PATH, "w") as f:
    yaml.safe_dump(new_yaml, f, sort_keys=False)

print("\nUpdated YAML written to:", YAML_PATH)
print("Final YAML keys:", list(new_yaml.keys()))

# --- 4) Verify no non-zero classes remain anywhere ---
offenders = []
for split, lbl_dir in label_dirs.items():
    for p in lbl_dir.rglob("*.txt"):
        txt = p.read_text(encoding="utf-8")
        # any line starting with 1..9
        if re.search(r'^\s*[1-9]\b', txt, flags=re.M):
            offenders.append(str(p))

print("\nVerification:", "CLEAN ✅ (only class 0 remains)" if not offenders else "Found non-zero classes ❌")
if offenders:
    print("\nSample offenders:")
    print("\n".join(offenders[:20]))
# Out:
# Discovered images dirs:
#   train: /content/strawberry-3/train/images
#   valid: /content/strawberry-3/valid/images
#   test: /content/strawberry-3/test/images
# Discovered label dirs:
#   train: /content/strawberry-3/train/labels
#   valid: /content/strawberry-3/valid/labels
#   test: /content/strawberry-3/test/labels
#
# Processed label files: 1920
# Kept class-0 (strawberry) lines: 3225
# Removed non-zero class lines: 1492
# Deleted empty-label images: 0 (DELETE_EMPTY_LABEL_IMAGES=False)
#
# Updated YAML written to: /content/strawberry-3/data.yaml
# Final YAML keys: ['train', 'val', 'test', 'nc', 'names', 'roboflow']
#
# Verification: CLEAN ✅ (only class 0 remains)

# %%
# Mount Drive only if your dataset is on Drive (skip if not needed)
# from google.colab import drive
# drive.mount('/content/drive')

from pathlib import Path
import yaml, re
from glob import glob

# === CONFIG: your YAML path ===
YAML_PATH = Path("/content/Avocado-Segmentation-3/data.yaml")  # <-- keep or change

ROOT = YAML_PATH.parent.resolve()

with open(YAML_PATH, "r") as f:
    y = yaml.safe_load(f)

def find_split_images_dir(split_name: str):
    # 1) use YAML if present, else 2) ROOT/split/images, else 3) recursive find
    if split_name in y:
        p = Path(y[split_name])
        p = (ROOT / p).resolve() if not p.is_absolute() else p
        if p.exists(): return p
    p2 = ROOT / split_name / "images"
    if p2.exists(): return p2
    hits = [Path(d) for d in glob(str(ROOT / "**/images"), recursive=True)
            if Path(d).parent.name.lower() == split_name]
    return hits[0] if hits else None

splits_order = ["train", "val", "valid", "test"]
img_dirs = {s: find_split_images_dir(s) for s in splits_order}
img_dirs = {k:v for k,v in img_dirs.items() if v is not None}
if not img_dirs:
    raise RuntimeError(f"Could not locate any images dirs under {ROOT}")

# labels dirs = sibling of images dir
label_dirs = {}
for split, img_dir in img_dirs.items():
    lbl_dir = img_dir.parent / "labels"
    if lbl_dir.exists():
        label_dirs[split] = lbl_dir

if not label_dirs:
    raise RuntimeError("No labels directories found. Expected .../<split>/labels")

def rewrite_label(lbl_path: Path):
    if not lbl_path.exists(): return (0,0,False)
    lines = [L.strip() for L in lbl_path.read_text(encoding="utf-8").splitlines() if L.strip()]
    out = []
    kept = removed = 0
    for L in lines:
        parts = L.split()
        try:
            _ = int(float(parts[0]))  # old class id (0/1/2)
        except:
            removed += 1
            continue
        # force single-class: set class id to 0 and keep the rest of coords
        parts[0] = "0"
        out.append(" ".join(parts))
        kept += 1
    lbl_path.write_text("\n".join(out), encoding="utf-8")
    return (kept, removed, len(out) == 0)

kept_total = removed_total = emptied_total = files_total = 0
for split, lbl_dir in label_dirs.items():
    for lbl_path in lbl_dir.rglob("*.txt"):
        files_total += 1
        k, r, emptied = rewrite_label(lbl_path)
        kept_total += k; removed_total += r
        if emptied: emptied_total += 1

print(f"Processed label files: {files_total}")
print(f"Kept lines (now class 0): {kept_total}")
print(f"Dropped malformed/blank lines: {removed_total}")

# Update YAML to single-class + normalize paths
new_yaml = dict(y)
new_yaml["names"] = ["avocado"]
new_yaml["nc"] = 1
def rel_from_root(p: Path): return str(p.relative_to(ROOT)).replace("\\","/")
if "train" in img_dirs: new_yaml["train"] = rel_from_root(img_dirs["train"])
if "val" in img_dirs:   new_yaml["val"]   = rel_from_root(img_dirs["val"])
elif "valid" in img_dirs: new_yaml["val"] = rel_from_root(img_dirs["valid"])
if "test" in img_dirs:  new_yaml["test"]  = rel_from_root(img_dirs["test"])

with open(YAML_PATH, "w") as f:
    yaml.safe_dump(new_yaml, f, sort_keys=False)

# Verify no non-zero class ids remain
offenders = []
for split, lbl_dir in label_dirs.items():
    for p in lbl_dir.rglob("*.txt"):
        txt = p.read_text(encoding="utf-8")
        if re.search(r'^\s*[1-9]\b', txt, flags=re.M):
            offenders.append(str(p))

print("Verification:", "CLEAN ✅ (only class 0 remains)" if not offenders else "Found non-zero classes ❌")
if offenders:
    print("\nSample offenders:\n", "\n".join(offenders[:20]))
# Out:
# Processed label files: 1580
# Kept lines (now class 0): 2882
# Dropped malformed/blank lines: 0
# Verification: CLEAN ✅ (only class 0 remains)

# %%
import os, shutil, re
from pathlib import Path
from glob import glob
from tqdm import tqdm
import yaml

# ==== CONFIG ====
# Where to write the merged dataset
MERGED_OUT = Path("/content/drive/MyDrive/3fruits/All_Fruits")  # change if you like

# Class order in the final dataset (this defines class IDs 0..4)
CLASS_ORDER = ["apple","banana","orange","avocado","strawberry"]

# Map each class to its existing single-class YAML
# Update any paths if yours differ.
CLASS_YAMLS = {
    "apple":      "/content/drive/MyDrive/3fruits/apple/data.yaml",
    "banana":     "/content/drive/MyDrive/3fruits/banana/data.yaml",
    "orange":     "/content/drive/MyDrive/3fruits/orange/data.yaml",
    "avocado":    "/content/drive/MyDrive/3fruits/Avocado/data.yaml",
    "strawberry": "/content/drive/MyDrive/3fruits/Strawberry/data.yaml",
}

# If the source dataset has a "test" split, where should we put it?
# Options: None (skip), "val" (merge test into val), or "test" (keep as test).
MERGE_TEST_TO = "val"
# =================

# Prepare merged folders
for split in ["train","val"] + (["test"] if MERGE_TEST_TO=="test" else []):
    (MERGED_OUT/f"images/{split}").mkdir(parents=True, exist_ok=True)
    (MERGED_OUT/f"labels/{split}").mkdir(parents=True, exist_ok=True)

def load_yaml(p: Path):
    with open(p, "r") as f:
        return yaml.safe_load(f)

def resolve_img_dir(y, root: Path, split_name: str):
    if split_name in y:
        p = Path(y[split_name])
        p = (root / p).resolve() if not p.is_absolute() else p
        if p.exists():
            return p
    # common layouts
    p2 = root / split_name / "images"
    if p2.exists():
        return p2
    # recursive: any .../<split>/images under root
    hits = [Path(d) for d in glob(str(root / "**/images"), recursive=True)
            if Path(d).parent.name.lower() == split_name]
    return hits[0] if hits else None

# Give each class a running index for filenames to avoid collisions
name_counters = {cls: 0 for cls in CLASS_ORDER}

def next_dst_name(cls: str, ext: str):
    name_counters[cls] += 1
    return f"{cls}_{name_counters[cls]:06d}{ext.lower()}"

def remap_and_copy_split(cls_name: str, src_img_dir: Path, dst_split: str, new_cls_id: int):
    """Copy images; rewrite labels to new class id. Keeps empty labels as negatives."""
    if not src_img_dir:
        return 0,0,0
    src_lbl_dir = src_img_dir.parent / "labels"
    if not src_lbl_dir.exists():
        print(f"[{cls_name}] Warning: labels dir missing for {src_img_dir}")
        return 0,0,0

    kept_lines = removed_lines = files = 0
    imgs = []
    for ext in ("*.jpg","*.jpeg","*.png","*.bmp","*.webp"):
        imgs += list(src_img_dir.rglob(ext))

    for img_path in tqdm(imgs, desc=f"{cls_name}:{dst_split}", leave=False):
        files += 1
        stem = img_path.stem
        lbl_src = src_lbl_dir / f"{stem}.txt"

        # Choose a unique destination filename
        dst_name = next_dst_name(cls_name, img_path.suffix)
        dst_img = MERGED_OUT / "images" / dst_split / dst_name
        dst_lbl = MERGED_OUT / "labels" / dst_split / (Path(dst_name).stem + ".txt")

        # Copy image
        shutil.copy2(img_path, dst_img)

        if lbl_src.exists():
            lines = [L.strip() for L in lbl_src.read_text(encoding="utf-8").splitlines() if L.strip()]
            out = []
            for L in lines:
                parts = L.split()
                # first token is class id; we ignore old value and set to global id
                # (works for seg and det)
                if not parts:
                    continue
                parts[0] = str(new_cls_id)
                out.append(" ".join(parts))
                kept_lines += 1
            # write label (can be empty -> negative sample)
            dst_lbl.write_text("\n".join(out), encoding="utf-8")
        else:
            # Create empty label file to keep negative image behavior
            dst_lbl.write_text("", encoding="utf-8")

    return files, kept_lines, removed_lines

# Merge loop
total_files = 0
for cls in CLASS_ORDER:
    yaml_path = Path(CLASS_YAMLS[cls])
    if not yaml_path.exists():
        print(f"⚠️ YAML not found for {cls}: {yaml_path} (skipping)")
        continue
    y = load_yaml(yaml_path)
    root = yaml_path.parent.resolve()
    new_cls_id = CLASS_ORDER.index(cls)

    img_train = resolve_img_dir(y, root, "train")
    img_val   = resolve_img_dir(y, root, "val") or resolve_img_dir(y, root, "valid")
    img_test  = resolve_img_dir(y, root, "test")

    f1, k1, _ = remap_and_copy_split(cls, img_train, "train", new_cls_id)
    f2, k2, _ = remap_and_copy_split(cls, img_val,   "val",   new_cls_id)

    if MERGE_TEST_TO in ("val", "test") and img_test:
        split_name = MERGE_TEST_TO
        if split_name == "test" and not (MERGED_OUT/"images/test").exists():
            (MERGED_OUT/"images/test").mkdir(parents=True, exist_ok=True)
            (MERGED_OUT/"labels/test").mkdir(parents=True, exist_ok=True)
        f3, k3, _ = remap_and_copy_split(cls, img_test, split_name, new_cls_id)
    else:
        f3 = k3 = 0

    total_files += (f1+f2+f3)
    print(f"[{cls}] train:{f1} val:{f2} test->{MERGE_TEST_TO}:{f3} (labels kept: {k1+k2+k3})")

print(f"\n✅ Merge complete. Total images copied: {total_files}")

# Write unified data.yaml
unified_yaml = {
    "path": str(MERGED_OUT.resolve()),
    "train": "images/train",
    "val": "images/val",
    "names": CLASS_ORDER
}
# include test only if created
if (MERGED_OUT/"images/test").exists():
    unified_yaml["test"] = "images/test"

with open(MERGED_OUT/"fruits.yaml", "w") as f:
    yaml.safe_dump(unified_yaml, f, sort_keys=False)

print("Unified YAML:", MERGED_OUT/"fruits.yaml")
# Out:
# [apple] train:900 val:100 test->val:0 (labels kept: 3884)
# [banana] train:900 val:100 test->val:0 (labels kept: 4429)
# [orange] train:900 val:100 test->val:0 (labels kept: 3889)
# [avocado] train:1437 val:95 test->val:48 (labels kept: 2882)
# [strawberry] train:1764 val:104 test->val:52 (labels kept: 3225)
#
# ✅ Merge complete. Total images copied: 6500
# Unified YAML: /content/drive/MyDrive/3fruits/All_Fruits/fruits.yaml

# %%
from pathlib import Path
import yaml, shutil, re

# ==== CONFIG ====
MERGE_ROOT = Path("/content/drive/MyDrive/3fruits/Yolo_seg2")  # unified dataset root
UNIFIED_YAML = MERGE_ROOT / "fruits.yaml"                      # unified yaml path

# Try both spellings; pick the one that exists
CANDIDATES = [Path("/content/drive/MyDrive/3fruits/Avocado/Avocado")]
AVO_ROOT = next((p for p in CANDIDATES if p.exists()), None)
assert AVO_ROOT and (AVO_ROOT / "data.yaml").exists(), "Avocado folder or data.yaml not found."

# Desired unified class order (edit if your order differs)
UNIFIED_NAMES = ["apple", "banana", "orange", "avocado", "strawberry"]
TARGET_CLASS = "avocado"
# =================

def load_or_create_unified_yaml():
    MERGE_ROOT.mkdir(parents=True, exist_ok=True)
    if UNIFIED_YAML.exists():
        with open(UNIFIED_YAML, "r") as f:
            y = yaml.safe_load(f) or {}
    else:
        y = {}
    # Ensure minimal fields
    y.setdefault("path", str(MERGE_ROOT))
    y.setdefault("train", "images/train")
    y.setdefault("val", "images/val")
    y.setdefault("names", UNIFIED_NAMES)
    # Normalize names to a simple list
    if isinstance(y.get("names"), dict):
        # convert {0:name0,1:name1,...} to list
        items = sorted(y["names"].items(), key=lambda kv: int(kv[0]))
        y["names"] = [name for _, name in items]
    # Ensure desired order (append any missing)
    for n in UNIFIED_NAMES:
        if n not in y["names"]:
            y["names"].append(n)
    y["nc"] = len(y["names"])

    # Write back
    with open(UNIFIED_YAML, "w") as f:
        yaml.safe_dump(y, f, sort_keys=False)
    return y

def find_split_images_dir(root: Path, yml: dict, split: str):
    # 1) if YAML has split path, use it (relative to root if needed)
    if split in yml:
        p = Path(yml[split])
        p = (root / p).resolve() if not p.is_absolute() else p
        if p.exists():
            return p
    # 2) common patterns
    for cand in [root / split / "images",
                 root / ({"val":"valid","valid":"valid"}.get(split, split)) / "images"]:
        if cand.exists():
            return cand
    # 3) recursive search: .../<split>/images
    hits = [Path(p) for p in root.rglob("images") if p.parent.name.lower() in (split, {"val":"valid"}.get(split, split))]
    return hits[0] if hits else None

def label_dir_for(img_dir: Path):
    lbl = img_dir.parent / "labels"
    return lbl if lbl.exists() else None

# Load/ensure unified YAML
unified = load_or_create_unified_yaml()
names = unified["names"]
try:
    target_id = names.index(TARGET_CLASS)
except ValueError:
    names.append(TARGET_CLASS)
    target_id = names.index(TARGET_CLASS)
    unified["names"] = names
    unified["nc"] = len(names)
    with open(UNIFIED_YAML, "w") as f:
        yaml.safe_dump(unified, f, sort_keys=False)

# Load avocado YAML
with open(AVO_ROOT / "data.yaml", "r") as f:
    avo_yaml = yaml.safe_load(f)

# Locate avocado split dirs
split_map = {"train":"train", "val":"val", "valid":"val", "test":"val"}  # send test -> val
img_dirs = {}
for s in ["train","val","valid","test"]:
    p = find_split_images_dir(AVO_ROOT, avo_yaml, s)
    if p: img_dirs[s] = p

assert img_dirs, "No avocado images dirs found."

# Prepare unified dirs
(dst_img_train, dst_lbl_train) = (MERGE_ROOT/"images/train", MERGE_ROOT/"labels/train")
(dst_img_val,   dst_lbl_val)   = (MERGE_ROOT/"images/val",   MERGE_ROOT/"labels/val")
for d in [dst_img_train, dst_lbl_train, dst_img_val, dst_lbl_val]:
    d.mkdir(parents=True, exist_ok=True)

def rewrite_and_copy(img_path: Path, src_lbl_dir: Path, dst_img_dir: Path, dst_lbl_dir: Path, prefix: str):
    # Build new base name with class prefix to avoid collisions
    new_base = f"{prefix}___{img_path.stem}"
    dst_img = dst_img_dir / f"{new_base}{img_path.suffix}"
    lbl_src = src_lbl_dir / f"{img_path.stem}.txt"
    dst_lbl = dst_lbl_dir / f"{new_base}.txt"

    if not lbl_src.exists():
        return False  # skip images without labels

    # Read, remap class id on every line to target_id
    lines = [L.strip() for L in lbl_src.read_text(encoding="utf-8").splitlines() if L.strip()]
    out = []
    for L in lines:
        parts = L.split()
        # first token should be class id
        if not parts:
            continue
        if not re.match(r"^-?\d+(\.\d+)?$", parts[0]):
            continue
        parts[0] = str(target_id)
        out.append(" ".join(parts))
    if not out:
        return False

    # Copy image and write label
    shutil.copy2(img_path, dst_img)
    dst_lbl.write_text("\n".join(out), encoding="utf-8")
    return True

# Do the merge
kept = 0
for split, img_dir in img_dirs.items():
    lbl_dir = label_dir_for(img_dir)
    if not lbl_dir:
        print(f"[avocado] Warning: labels dir missing for {img_dir}")
        continue
    target_split = split_map[split]
    dimg = dst_img_train if target_split=="train" else dst_img_val
    dlbl = dst_lbl_train if target_split=="train" else dst_lbl_val
    images = [p for p in img_dir.iterdir() if p.suffix.lower() in {".jpg",".jpeg",".png",".bmp",".tif",".tiff"}]
    for im in images:
        if rewrite_and_copy(im, lbl_dir, dimg, dlbl, prefix="avocado"):
            kept += 1

print(f"✅ Avocado merge done. Images copied with labels: {kept}")
print("Unified YAML:", UNIFIED_YAML)
# Out:
# ✅ Avocado merge done. Images copied with labels: 1342
# Unified YAML: /content/drive/MyDrive/3fruits/Yolo_seg2/fruits.yaml

# %%
import os, glob

root = "/content/drive/MyDrive/3fruits"
classes = ["apple","banana","orange","avocado","strawberry"]

for cls in classes:
    for split in ["train","val"]:
        img_dir = os.path.join(root, cls, "images", split)
        lab_dir = os.path.join(root, cls, "labels", split)
        if not os.path.isdir(img_dir):
            continue
        if not os.path.isdir(lab_dir):
            print(f"[{cls}] Missing {lab_dir}")
            continue
        imgs = sorted(glob.glob(os.path.join(img_dir, "*.*")))
        missing = []
        for im in imgs:
            name = os.path.splitext(os.path.basename(im))[0]
            if not os.path.exists(os.path.join(lab_dir, name + ".txt")):
                missing.append(name)
        print(f"[{cls}] {split}: {len(imgs)} imgs, {len(missing)} without labels",
              ("-> e.g. " + ", ".join(missing[:5])) if missing else "")
# Out:
# [apple] train: 900 imgs, 0 without labels
# [apple] val: 100 imgs, 0 without labels
# [banana] train: 900 imgs, 0 without labels
# [banana] val: 100 imgs, 0 without labels
# [orange] train: 900 imgs, 0 without labels
# [orange] val: 100 imgs, 0 without labels

# %%
from pathlib import Path
import shutil

src = Path("/content/drive/MyDrive/3fruits/orange/labels/val")
dst = Path("/content/drive/MyDrive/3fruits/orange/val/labels")
dst.mkdir(parents=True, exist_ok=True)

# move all files/folders inside src into dst
for item in src.iterdir():
    shutil.move(str(item), str(dst / item.name))

# (optional) remove now-empty source directory
try:
    src.rmdir()  # only succeeds if it's empty
except OSError:
    pass

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.193-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.23.0+cu126)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.25.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.17-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.193-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.8 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.17-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.193 ultralytics-thop-2.0.17
